# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium.common.exceptions import NoSuchElementException
from bs4 import BeautifulSoup
import time

def crawl_movies_fixed_scroll(keyword, max_pages=8, scroll_position=800):
    options = Options()
    options.add_argument('--headless')
    options.add_argument('--disable-gpu')
    options.add_argument('window-size=1920x1080')
    options.add_argument('--disable-blink-features=AutomationControlled')
    options.add_argument("user-agent=Mozilla/5.0")

    driver = webdriver.Chrome(options=options)
    url = "https://search.naver.com/search.naver?query=현재상영영화"
    driver.get(url)
    time.sleep(2)

    results = []
    page = 1
    keyword = keyword.lower()  # 대소문자 구분 없이 비교

    while page <= max_pages:
        # print(f"\n[📄 {page}페이지 크롤링 중...]")

        driver.execute_script(f"window.scrollTo(0, {scroll_position});")
        time.sleep(1)

        soup = BeautifulSoup(driver.page_source, "html.parser")
        movies = soup.select("div.data_area")

        for movie in movies:
            title_tag = movie.select_one("div.title a.this_text")
            title = title_tag.text.strip() if title_tag else ""

            img_tag = movie.select_one("a.img_box img")
            poster = img_tag["src"] if img_tag and img_tag.has_attr("src") else "이미지 없음"

            overview_tag = movie.select_one("dl.info_group dd")
            overview = overview_tag.text.strip() if overview_tag else "개요 없음"

            rating_tag = movie.select_one("dl.info_group.type_visible dd span.num")
            rating = rating_tag.text.strip() if rating_tag else "별점 없음"

            # 🔍 제목과 개요 모두를 소문자로 비교
            title_lower = title.lower()
            overview_lower = overview.lower()

            # 🔍 개요가 "장르1/장르2" 형태일 수 있으므로 "/"로 나눔
            overview_parts = [part.strip() for part in overview_lower.split('/')]

            # 🔍 조건: 제목에 keyword가 포함되거나, 개요의 각 요소 중 하나라도 keyword 포함
            if keyword in title_lower or any(keyword in part for part in overview_parts):
                results.append({
                    "제목": title,
                    "별점": rating,
                    "개요": overview,
                    "포스터": poster
                })

        # 다음 페이지 이동
        try:
            next_btn = driver.find_element(By.CSS_SELECTOR, "a.pg_next")
            if next_btn.get_attribute("aria-disabled") == "true":
                # print("⛔️ 더 이상 다음 페이지가 없습니다.")
                break
            next_btn.click()
            page += 1
            time.sleep(2)
        except NoSuchElementException:
            print("❌ 다음 버튼이 없습니다.")
            break

    driver.quit()
    return results

# 실행
if __name__ == "__main__":
    keyword = input("제목 또는 개요 키워드 입력: ")
    data = crawl_movies_fixed_scroll(keyword)

    if data:
        for movie in data:
            print("\n🎬 제목:", movie["제목"])
            print("⭐️ 별점:", movie["별점"])
            print("📝 개요:", movie["개요"])
            print("🖼 포스터:", movie["포스터"])
    else:
        print("❌ 해당 키워드의 영화가 없습니다.")
# Out:
# 🎬 제목: F1 더 무비
# ⭐️ 별점: 8.99
# 📝 개요: 드라마
# 🖼 포스터: https://search.pstatic.net/common?type=o&size=304x456&quality=100&direct=true&src=https%3A%2F%2Fs.pstatic.net%2Fmovie.phinf%2F20250605_102%2F1749114555681W3FeM_JPEG%2Fmovie_image.jpg%3Ftype%3Dw640_2
#
# 🎬 제목: 우리들의 교복시절
# ⭐️ 별점: 8.54
# 📝 개요: 드라마
# 🖼 포스터: https://search.pstatic.net/common?type=o&size=304x456&quality=100&direct=true&src=https%3A%2F%2Fs.pstatic.net%2Fmovie.phinf%2F20250624_232%2F1750750905510HdojY_JPEG%2Fmovie_image.jpg%3Ftype%3Dw640_2
#
# 🎬 제목: 스왈로우테일 버터플라이
# ⭐️ 별점: 7.33
# 📝 개요: 드라마
# 🖼 포스터: https://search.pstatic.net/common?type=o&size=304x456&quality=100&direct=true&src=https%3A%2F%2Fs.pstatic.net%2Fmovie.phinf%2F20250630_8%2F17512517720636r8bq_JPEG%2Fmovie_image.jpg%3Ftype%3Dw640_2
#
# 🎬 제목: 신명
# ⭐️ 별점: 8.46
# 📝 개요: 드라마
# 🖼 포스터: https://search.pstatic.net/common?type=o&size=304x456&quality=100&direct=true&src=https%3A%2F%2Fs.pstatic.net%2Fmovie.phinf%2F20250708_269%2F1751941750043ccLYe_JPEG%2Fmovie_image.jpg%3Ftype%3Dw640_2
#
# 🎬 제목: 델마와 루이스
# ⭐️ 별점: 9.06
# 📝 개요: 드라마
# 🖼 포스터: https://search.pstatic.net/common?type=o&size=304x456&quality=100&direct=true&src=https%3A%2F%2Fs.pstatic.net%2Fmovie.phinf%2F20250708_10%2F1751940690582VlqWJ_JPEG%2Fmovie_image.jpg%3Ftype%3Dw640_2
#
# 🎬 제목: 라이언 일병 구하기
# ⭐️ 별점: 9.37
# 📝 개요: 드라마
# 🖼 포스터: https://search.pstatic.net/common?type=o&size=304x456&quality=100&direct=true&src=https%3A%2F%2Fs.pstatic.net%2Fmovie.phinf%2F20250616_178%2F1750036980352yyNYp_JPEG%2Fmovie_image.jpg%3Ftype%3Dw640_2
#
# 🎬 제목: 여름이 지나가면
# ⭐️ 별점: 8.13
# 📝 개요: 드라마
# 🖼 포스터: https://search.pstatic.net/common?type=o&size=304x456&quality=100&direct=true&src=https%3A%2F%2Fs.pstatic.net%2Fmovie.phinf%2F20250625_280%2F1750819788979NU62G_JPEG%2Fmovie_image.jpg%3Ftype%3Dw640_2
#
# 🎬 제목: 미세리코르디아
# ⭐️ 별점: 7.00
# 📝 개요: 드라마
# 🖼 포스터: https://search.pstatic.net/common?type=o&size=304x456&quality=100&direct=true&src=https%3A%2F%2Fs.pstatic.net%2Fmovie.phinf%2F20250701_199%2F17513615578891WQ7K_JPEG%2Fmovie_image.jpg%3Ftype%3Dw640_2
#
# 🎬 제목: 봄밤
# ⭐️ 별점: 7.61
# 📝 개요: 드라마
# 🖼 포스터: https://search.pstatic.net/common?type=o&size=304x456&quality=100&direct=true&src=https%3A%2F%2Fs.pstatic.net%2Fmovie.phinf%2F20250617_20%2F1750135254187dv47B_JPEG%2Fmovie_image.jpg%3Ftype%3Dw640_2
#
# 🎬 제목: 시네마 천국
# ⭐️ 별점: 9.56
# 📝 개요: 드라마
# 🖼 포스터: https://search.pstatic.net/common?type=o&size=304x456&quality=100&direct=true&src=https%3A%2F%2Fs.pstatic.net%2Fmovie.phinf%2F20250619_69%2F1750300301657ccgqv_JPEG%2Fmovie_image.jpg%3Ftype%3Dw640_2
#
# 🎬 제목: 퀴어
# ⭐️ 별점: 6.97
# 📝 개요: 드라마
# 🖼 포스터: https://search.pstatic.net/common?type=o&size=304x456&quality=100&direct=true&src=https%3A%2F%2Fs.pstatic.net%2Fmovie.phinf%2F20250620_278%2F1750408885354kP7De_JPEG%2Fmovie_image.jpg%3Ftype%3Dw640_2
#
# 🎬 제목: 해피엔드
# ⭐️ 별점: 8.19
# 📝 개요: 드라마
# 🖼 포스터: https://search.pstatic.net/common?type=o&size=304x456&quality=100&direct=true&src=https%3A%2F%2Fs.pstatic.net%2Fmovie.phinf%2F20250326_250%2F1742954673142sazXq_JPEG%2Fmovie_image.jpg%3Ftype%3Dw640_2
#
# 🎬 제목: 그을린 사랑
# ⭐️ 별점: 8.85
# 📝 개요: 드라마
# 🖼 포스터: https://search.pstatic.net/common?type=o&size=304x456&quality=100&direct=true&src=https%3A%2F%2Fs.pstatic.net%2Fmovie.phinf%2F20250630_221%2F17512651629809oNSG_JPEG%2Fmovie_image.jpg%3Ftype%3Dw640_2
#
# 🎬 제목: 바다호랑이
# ⭐️ 별점: 10.00
# 📝 개요: 드라마
# 🖼 포스터: https://search.pstatic.net/common?type=o&size=304x456&quality=100&direct=true&src=https%3A%2F%2Fs.pstatic.net%2Fmovie.phinf%2F20250612_276%2F17497097193199hwHr_JPEG%2Fmovie_image.jpg%3Ftype%3Dw640_2
#
# 🎬 제목: 꿈꾸는 사진관
# ⭐️ 별점: 10.00
# 📝 개요: 드라마
# 🖼 포스터: https://search.pstatic.net/common?type=o&size=304x456&quality=100&direct=true&src=https%3A%2F%2Fs.pstatic.net%2Fmovie.phinf%2F20250115_192%2F1736920831762xxGrl_JPEG%2Fmovie_image.jpg%3Ftype%3Dw640_2
#
# 🎬 제목: 네이키드 런치
# ⭐️ 별점: 7.30
# 📝 개요: 드라마
# 🖼 포스터: https://search.pstatic.net/common?type=o&size=304x456&quality=100&direct=true&src=https%3A%2F%2Fs.pstatic.net%2Fmovie.phinf%2F20250616_144%2F175003552564017git_JPEG%2Fmovie_image.jpg%3Ftype%3Dw640_2
#
# 🎬 제목: 인생은 아름다워
# ⭐️ 별점: 9.21
# 📝 개요: 드라마
# 🖼 포스터: https://search.pstatic.net/common?type=o&size=304x456&quality=100&direct=true&src=https%3A%2F%2Fs.pstatic.net%2Fmovie.phinf%2F20250514_158%2F17472053247308jaQh_JPEG%2Fmovie_image.jpg%3Ftype%3Dw640_2
#
# 🎬 제목: 귤레귤레
# ⭐️ 별점: 8.56
# 📝 개요: 드라마
# 🖼 포스터: https://search.pstatic.net/common?type=o&size=304x456&quality=100&direct=true&src=https%3A%2F%2Fs.pstatic.net%2Fmovie.phinf%2F20250526_58%2F17482386028217XBhg_JPEG%2Fmovie_image.jpg%3Ftype%3Dw640_2
#
# 🎬 제목: 페니키안 스킴
# ⭐️ 별점: 7.31
# 📝 개요: 드라마
# 🖼 포스터: https://search.pstatic.net/common?type=o&size=304x456&quality=100&direct=true&src=https%3A%2F%2Fs.pstatic.net%2Fmovie.phinf%2F20250509_219%2F1746779391303yYBcr_JPEG%2Fmovie_image.jpg%3Ftype%3Dw640_2
#
# 🎬 제목: 순응자
# ⭐️ 별점: 8.41
# 📝 개요: 드라마
# 🖼 포스터: https://search.pstatic.net/common?type=o&size=304x456&quality=100&direct=true&src=https%3A%2F%2Fs.pstatic.net%2Fmovie.phinf%2F20250611_152%2F1749605624183SvOzM_JPEG%2Fmovie_image.jpg%3Ftype%3Dw640_2
#
# 🎬 제목: 아마데우스 오리지널 리마스터링
# ⭐️ 별점: 9.29
# 📝 개요: 드라마
# 🖼 포스터: https://search.pstatic.net/common?type=o&size=304x456&quality=100&direct=true&src=https%3A%2F%2Fs.pstatic.net%2Fmovie.phinf%2F20250512_268%2F1747015893195oCi7u_JPEG%2Fmovie_image.jpg%3Ftype%3Dw640_2
#
# 🎬 제목: 내가 누워있을 때
# ⭐️ 별점: 9.42
# 📝 개요: 드라마
# 🖼 포스터: https://search.pstatic.net/common?type=o&size=304x456&quality=100&direct=true&src=https%3A%2F%2Fs.pstatic.net%2Fmovie.phinf%2F20250513_135%2F1747111316221YDSv4_JPEG%2Fmovie_image.jpg%3Ftype%3Dw640_2

# %%
# 필요한 라이브러리 임포트
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium.common.exceptions import NoSuchElementException
from bs4 import BeautifulSoup
import time

# 현재상영영화 페이지를 크롤링하는 함수 정의
def crawl_movies_fixed_scroll(keyword, max_pages=8, scroll_position=800):
    options = Options()  # Chrome 옵션 설정 객체 생성
    options.add_argument('--headless')  # 브라우저 창을 띄우지 않도록 설정 (백그라운드 실행)
    options.add_argument('--disable-gpu')  # GPU 사용 안함 (headless 모드에서 필수는 아님)
    options.add_argument('window-size=1920x1080')  # 브라우저 창 크기 설정
    options.add_argument('--disable-blink-features=AutomationControlled')  # 자동화 감지 방지
    options.add_argument("user-agent=Mozilla/5.0")  # User-Agent 설정 (봇으로 오인 방지)

    driver = webdriver.Chrome(options=options)  # 위 옵션으로 크롬 드라이버 실행
    url = "https://search.naver.com/search.naver?query=현재상영영화"  # 검색할 URL
    driver.get(url)  # 해당 URL로 이동
    time.sleep(2)  # 페이지 로딩 대기

    results = []  # 수집한 영화 정보를 저장할 리스트
    page = 1  # 시작 페이지 번호
    keyword = keyword.lower()  # 입력한 키워드를 소문자로 변환 (대소문자 무시)

    while page <= max_pages:  # 최대 페이지 수만큼 반복
        # driver.execute_script를 통해 지정 위치로 스크롤 이동
        driver.execute_script(f"window.scrollTo(0, {scroll_position});")
        time.sleep(1)  # 스크롤 후 약간 대기 (렌더링 시간)

        soup = BeautifulSoup(driver.page_source, "html.parser")  # 현재 페이지의 HTML을 파싱
        movies = soup.select("div.data_area")  # 영화 데이터가 있는 블록들을 모두 선택

        for movie in movies:  # 각 영화에 대해 반복
            title_tag = movie.select_one("div.title a.this_text")  # 영화 제목 태그 선택
            title = title_tag.text.strip() if title_tag else ""  # 텍스트 추출 (없으면 빈 문자열)

            img_tag = movie.select_one("a.img_box img")  # 포스터 이미지 태그 선택
            poster = img_tag["src"] if img_tag and img_tag.has_attr("src") else "이미지 없음"  # 포스터 URL 추출

            overview_tag = movie.select_one("dl.info_group dd")  # 개요 정보 추출
            overview = overview_tag.text.strip() if overview_tag else "개요 없음"  # 개요 텍스트 추출

            rating_tag = movie.select_one("dl.info_group.type_visible dd span.num")  # 별점 태그 선택
            rating = rating_tag.text.strip() if rating_tag else "별점 없음"  # 별점 텍스트 추출

            title_lower = title.lower()  # 제목을 소문자로 변환
            overview_lower = overview.lower()  # 개요도 소문자로 변환

            overview_parts = [part.strip() for part in overview_lower.split('/')]  # 개요를 "/"로 나누고 공백 제거

            # 제목 또는 개요 중 하나라도 키워드 포함 시 저장
            if keyword in title_lower or any(keyword in part for part in overview_parts):
                results.append({
                    "제목": title,
                    "별점": rating,
                    "개요": overview,
                    "포스터": poster
                })

        # 다음 페이지 이동 시도
        try:
            next_btn = driver.find_element(By.CSS_SELECTOR, "a.pg_next")  # 다음 버튼 찾기
            if next_btn.get_attribute("aria-disabled") == "true":  # 더 이상 페이지가 없으면 종료
                break
            next_btn.click()  # 다음 버튼 클릭
            page += 1  # 페이지 번호 증가
            time.sleep(2)  # 페이지 로딩 대기
        except NoSuchElementException:  # 다음 버튼이 없는 경우
            print("❌ 다음 버튼이 없습니다.")  # 에러 메시지 출력
            break

    driver.quit()  # 드라이버 종료 (브라우저 닫기)
    return results  # 결과 리스트 반환

# 프로그램 실행 구문
if __name__ == "__main__":
    keyword = input("제목 또는 개요 키워드 입력: ")  # 사용자에게 키워드 입력 받기
    data = crawl_movies_fixed_scroll(keyword)  # 함수 호출하여 영화 데이터 수집

    if data:  # 결과가 있다면 출력
        for movie in data:
            print("\n🎬 제목:", movie["제목"])
            print("⭐️ 별점:", movie["별점"])
            print("📝 개요:", movie["개요"])
            print("🖼 포스터:", movie["포스터"])
    else:
        print("❌ 해당 키워드의 영화가 없습니다.")  # 결과가 없을 때 메시지 출력
