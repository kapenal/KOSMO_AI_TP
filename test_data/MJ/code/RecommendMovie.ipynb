# %%
# 더미 데이터를 훈련, 테스트 데이터로 나누고 파일로 저장

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# 1. 데이터 불러오기
review_dummy_df = pd.read_csv('../data/review_dummy.txt', sep='\t')

# 데이터 확인
print(" === 데이터 상위 5개 === \n", review_dummy_df.head())
print(" === review_dummy_df.info() ===")
review_dummy_df.info()
print("\n === label 컬럼 확인 === \n", review_dummy_df['label'].value_counts())
print("\n === label 유니크 값 === \n", review_dummy_df['label'].unique())
print('review_dummy_df 데이터 확인')
review_dummy_df

# 2. 잘못 들어간 행 제거
review_dummy_df = review_dummy_df[review_dummy_df['label'] != 'label']
# 4. label 컬럼을 숫자형으로 변환
review_dummy_df['label'] = review_dummy_df['label'].astype(int)

# 5. train / test 분리
train_df, test_df = train_test_split(
    review_dummy_df,
    test_size=0.2,
    random_state=42,
    stratify=review_dummy_df['label']
)
print(f"Train 데이터 개수: {len(train_df)}")
print(f"Test 데이터 개수: {len(test_df)}")

# 8. 저장
train_df.to_csv('../data/train_data.txt', sep='\t', index=False, encoding='utf-8')
test_df.to_csv('../data/test_data.txt', sep='\t', index=False, encoding='utf-8')
# Out:
#  === 데이터 상위 5개 ===
#          id                                           document label
# 0  6270596                                                굳 ㅋ     1
# 1  9274899                               GDNTOPCLASSINTHECLUB     0
# 2  8544678             뭐야 이 평점들은.... 나쁘진 않지만 10점 짜리는 더더욱 아니잖아     0
# 3  6825595                   지루하지는 않은데 완전 막장임... 돈주고 보기에는....     0
# 4  6723715  3D만 아니었어도 별 다섯 개 줬을텐데.. 왜 3D로 나와서 제 심기를 불편하게 하죠??     0
#  === review_dummy_df.info() ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200001 entries, 0 to 200000
# Data columns (total 3 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   id        200001 non-null  object
#  1   document  199993 non-null  object
#  2   label     200001 non-null  object
# dtypes: object(3)
# memory usage: 4.6+ MB
#
#  === label 컬럼 확인 ===
#  label
# 1        100000
# 0        100000
# label         1
# Name: count, dtype: int64
#
#  === label 유니크 값 ===
#  ['1' '0' 'label']
# review_dummy_df 데이터 확인
# Train 데이터 개수: 160000
# Test 데이터 개수: 40000

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report
import re

# 학습 데이터 파일 로드
try:
    train_df = pd.read_csv('../data/train_data.txt', sep='\t')
    test_df = pd.read_csv('../data/train_data.txt', sep='\t')
except FileNotFoundError:
    print("Error: 'ratings_train.txt' or 'ratings_test.txt' not found.")
    print("Please download them from https://github.com/e9t/nsmc and place them in the same directory as this script.")
    exit()

# 결측치 제거 (학습을 위해)
train_df = train_df.dropna(how='any')
test_df = test_df.dropna(how='any')

# 텍스트 전처리 (정규표현식)
def clean_text(text):
    text = re.sub(r'[^가-힣\s]', '', text) # 한글과 공백만 남김
    return text
train_df['document'] = train_df['document'].apply(clean_text)
test_df['document'] = test_df['document'].apply(clean_text)

# 모델 학습/테스트를 위한 데이터셋 분리
X_train = train_df['document']
y_train = train_df['label']
X_test = test_df['document']
y_test = test_df['label']

# 텍스트 벡터화 (TF-IDF)
# ngram_range=(1, 2): ‘스토리’, ‘스토리 좋다’ 같은 단어 묶음도 학습.
tfidf_vectorizer = TfidfVectorizer(min_df=3, ngram_range=(1, 2))

# 어휘 학습
# 텍스트 → 숫자 벡터로 바꾸기 위한 단어 사전 생성
tfidf_vectorizer.fit(X_train)
# transform 적용 (어휘 학습 및 변환)
X_train_tfidf = tfidf_vectorizer.transform(X_train)
X_test_tfidf = tfidf_vectorizer.transform(X_test)

# 모델 학습 (로지스틱 회귀)
# 벡터화된 숫자 데이터를 이용해 긍정/부정 분류 모델 학습
model = LogisticRegression(random_state=42, solver='liblinear', C=1.0)
model.fit(X_train_tfidf, y_train)

# 4. 모델 평가
# 테스트 데이터셋으로 모델 성능을 평가합니다.
model_predict = model.predict(X_test_tfidf)

# 정확도 계산 (실제 정답, 모델 예측 결과)
accuracy = accuracy_score(y_test, model_predict)
print(f"모델 정확도 : {accuracy:.4f}")
# Out:
# 모델 정확도 : 0.8545

# %%
# 모델 평가 지표
print("\n모델 평가 지표:")
print(classification_report(y_test, model_predict,
                            target_names=['긍정(Negative)(0)', '부정(Positive)(1)']))
# Out:
# 모델 평가 지표:
#                  precision    recall  f1-score   support
#
# 긍정(Negative)(0)       0.82      0.90      0.86     79996
# 부정(Positive)(1)       0.89      0.81      0.85     79998
#
#        accuracy                           0.85    159994
#       macro avg       0.86      0.85      0.85    159994
#    weighted avg       0.86      0.85      0.85    159994

# %%
# 리뷰 긍/부정 감정 예측 함수
def predict_sentiment_fc(new_review):
    # 입력 텍스트 전처리
    cleaned_review = clean_text(new_review)
    # 텍스트를 벡터화
    new_review_tfidf = tfidf_vectorizer.transform([cleaned_review])
    # 모델로 예측
    prediction = model.predict(new_review_tfidf)[0]
    # 긍/부정일 확률 각각 계산
    prediction_proba = model.predict_proba(new_review_tfidf)[0]
    sentiment = "긍정(Positive)" if prediction == 1 else "부정(Negative)"

    print(f"\n--- 예측 결과 ---")
    print(f"리뷰: '{new_review}'")
    print(f"리뷰 반응: {sentiment}")
    print(f"긍정 확률: {prediction_proba[1]:.4f}, 부정 확률: {prediction_proba[0]:.4f}")
    
    return sentiment, prediction_proba

# %%
# -----------------------------------------------------------------------

# %%
# 새로운 리뷰 테스트
print("\n--- 새로운 리뷰 예측 테스트 ---")
review1 = "이 영화 정말 최고였어요! 배우들 연기도 좋고 스토리도 완벽합니다."
predict_sentiment_fc(review1)
review2 = "시간 낭비였어요. 지루하고 개연성도 없네요. 추천하지 않습니다."
predict_sentiment_fc(review2)
review3 = "그럭저럭 볼만했습니다. 기대했던 것보다는 아니지만 나쁘지 않았어요."
predict_sentiment_fc(review3)
# Out:
# --- 새로운 리뷰 예측 테스트 ---
#
# --- 예측 결과 ---
# 리뷰: '이 영화 정말 최고였어요! 배우들 연기도 좋고 스토리도 완벽합니다.'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.9362, 부정 확률: 0.0638
#
# --- 예측 결과 ---
# 리뷰: '시간 낭비였어요. 지루하고 개연성도 없네요. 추천하지 않습니다.'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.0233, 부정 확률: 0.9767
#
# --- 예측 결과 ---
# 리뷰: '그럭저럭 볼만했습니다. 기대했던 것보다는 아니지만 나쁘지 않았어요.'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.5687, 부정 확률: 0.4313
# ('긍정(Positive)', array([0.43128783, 0.56871217]))

# %%
# 위 함수를 이용해 크롤링한 영화 리뷰 긍/부정 판결

# 리뷰 데이터 불러오기
reviews_df = pd.read_csv('E:/KOSMO/TeamProject/KOSMO_AI_TP/test_data/MJ/data/reviews.csv')
reviews_df

# 리뷰 데이터에 감정 라벨링
sentiments = []
for review in reviews_df['review']:
    sentiment, Probability = predict_sentiment_fc(review)
    sentiments.append(sentiment)

# 새 컬럼으로 추가
reviews_df['sentiment'] = sentiments
  
# 새 파일로 저장
reviews_df.to_csv('../data/fi_reviews.csv', index=False, encoding='utf-8')
# Out:
# --- 예측 결과 ---
# 리뷰: '너무많이봐서기억도안나'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '남녀주인공 볼라고 보는 드라마 아님
# 나는 추자현 연기 볼려고 견우본닼ㅋㅋㅋㅋ 심지어 남녀주인공 건뛰
# ㅋㅋㅋㅋㅋ😂연기 찰지게 잘하셔 트리거에서도 몰입도 짱이였는데 👍'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4976, 부정 확률: 0.5024
#
# --- 예측 결과 ---
# 리뷰: '마왕과나'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '재밌네 ㅋㅋㅋㅋ이현이 보러 가즈아~~~'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.9015, 부정 확률: 0.0985
#
# --- 예측 결과 ---
# 리뷰: '인형의기사'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '조이현 너무너무 귀엽고 이쁘게 나오고
# 너무 재미있어요❤️❤️❤️❤️❤️'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.9471, 부정 확률: 0.0529
#
# --- 예측 결과 ---
# 리뷰: '귀여운 타란티노_43609'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.8712, 부정 확률: 0.1288
#
# --- 예측 결과 ---
# 리뷰: '재밌음'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.9863, 부정 확률: 0.0137
#
# --- 예측 결과 ---
# 리뷰: '즐거운_마동석_209083'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '2화까지 - 이거왜재밌음? 돌풍감독이라 함 보았는데 탄탄하다'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.6864, 부정 확률: 0.3136
#
# --- 예측 결과 ---
# 리뷰: '상냥한_슈카_128005'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '조이현 너무너무 이쁨ㅜㅜ'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.8894, 부정 확률: 0.1106
#
# --- 예측 결과 ---
# 리뷰: '하다니'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.3917, 부정 확률: 0.6083
#
# --- 예측 결과 ---
# 리뷰: '조이현 와 이리 귀여움?
# 가끔 과하긴 하지만 외모가 다해주네
# 스토리는 애들이 좋아할 정도지만 귀여우니 됐다'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4176, 부정 확률: 0.5824
#
# --- 예측 결과 ---
# 리뷰: '니가그렇지모'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '귀엽네 성인시절로는 안가나'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.5291, 부정 확률: 0.4709
#
# --- 예측 결과 ---
# 리뷰: '메리'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.5714, 부정 확률: 0.4286
#
# --- 예측 결과 ---
# 리뷰: '일단 지금까진 흥미롭고 귀여움
# 하이틴로코의 정석같은 맛'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.8821, 부정 확률: 0.1179
#
# --- 예측 결과 ---
# 리뷰: '요키치'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '대부분의 관객이 실패 없이 관람 가능한 극장용 영화. 개인적으로는 탑건보다는 조금 모자랐다.'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.2635, 부정 확률: 0.7365
#
# --- 예측 결과 ---
# 리뷰: '귀여운_침착맨_569931'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: 'F1이 주는 쾌감 장닌아님 ㅎㅎㅎㅎ'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.7718, 부정 확률: 0.2282
#
# --- 예측 결과 ---
# 리뷰: 'KrisKelbin'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '하늘에는 매버릭, 땅 위에는 헤이스. (플랜 C는 Classic의 C)'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: 'PROERA'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '0.1초를 단축하려는 세계를 0.1초라도 더 점유하고 싶은 강렬한 역설'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.7576, 부정 확률: 0.2424
#
# --- 예측 결과 ---
# 리뷰: '키높이오'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '저 아직 안전벨트 안맸는데 달리시면 어떡해요...'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.5228, 부정 확률: 0.4772
#
# --- 예측 결과 ---
# 리뷰: '도도한_567681'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '완전 대박'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.9154, 부정 확률: 0.0846
#
# --- 예측 결과 ---
# 리뷰: '낯선사람'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '멀리있던 F1이 가장 가까이 다가온다.'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.7803, 부정 확률: 0.2197
#
# --- 예측 결과 ---
# 리뷰: '싹싹한_엠마스톤_295829'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '어떤영화들은 체험된다'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '푸린세스'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '짧지않은 러닝타임이였지만 지루할 틈을 안준다'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.7377, 부정 확률: 0.2623
#
# --- 예측 결과 ---
# 리뷰: 'ㄱㅁㄱ'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: 'F1이 관심이 많은사람뿐만 아니라 잘 모르는 사람에게도 최고의 레이싱 영화'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.8169, 부정 확률: 0.1831
#
# --- 예측 결과 ---
# 리뷰: '고고한_엠마스톤_106605'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '쿠플에 있길래 별 기대없이 봤는데 대존잼임
# 오늘 3회 대기중 ㅋㅋㅋ'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.8911, 부정 확률: 0.1089
#
# --- 예측 결과 ---
# 리뷰: '시즈씨'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '배우들의 노고만 으로도 🥹👍 괜찮은 #k- 장르물!'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.9335, 부정 확률: 0.0665
#
# --- 예측 결과 ---
# 리뷰: '행복한_송혜교_605203'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '가볍게 보기 좋아유'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.6708, 부정 확률: 0.3292
#
# --- 예측 결과 ---
# 리뷰: '상냥한_엘사_909587'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '뻔하다. 그런데 fun하다'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.2156, 부정 확률: 0.7844
#
# --- 예측 결과 ---
# 리뷰: 'junhyeong416'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '이 각본 이 조합 이 스타일로 시즌 이어나가길'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.6852, 부정 확률: 0.3148
#
# --- 예측 결과 ---
# 리뷰: '박도하'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '재밌기는 한데 추리는 별로 없고 액션?이 주라서 좀 답답함
# 차라리 그냥 소소하게 일상 사건 해결하는 초반이 좋았던듯'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.0524, 부정 확률: 0.9476
#
# --- 예측 결과 ---
# 리뷰: '비디오가게'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '시트콤인줄 알고 봤더니 추척60분 이었다.'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.2817, 부정 확률: 0.7183
#
# --- 예측 결과 ---
# 리뷰: '낙관주의민'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '계속 보게 된다. 잘만들었다는 뜻이다. 하지만 내가 지금 이렇게 시간 낭비해도 되나'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4270, 부정 확률: 0.5730
#
# --- 예측 결과 ---
# 리뷰: '재밌는_유재석_881463'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '이렇다할 캐릭터는 없지만 여성들의 연대로 사건을 해결하는 통쾌함은 있음'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.3900, 부정 확률: 0.6100
#
# --- 예측 결과 ---
# 리뷰: '싹싹한_티모시_327815'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '추리극을 기대하고 보기엔 추리 위주가 아님.
# 대사가 유치한 부분이 다소 있음(특히 정영주 배우 대사)
# 가볍게 보기엔 좋은 드라마'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.3023, 부정 확률: 0.6977
#
# --- 예측 결과 ---
# 리뷰: '친절한_짱구_536087'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '진짜 최악의 연출ㅎㅎ 학폭씬 연출하는데 고층아파트에 둘러싸인 학교옥상에서 친구 줘패는 거 보고 바로 꺼버림. 위에 수천개의 눈이 달렸는데 아무도 신고 안한다고?ㅎㅎ'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.0847, 부정 확률: 0.9153
#
# --- 예측 결과 ---
# 리뷰: '낯선사람'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '일단 소재는 신선.'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.2291, 부정 확률: 0.7709
#
# --- 예측 결과 ---
# 리뷰: '도도한_올라프_930741'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '이 참신한 소재와 배우들을 가지고
# 스토리 전개, 연출 최악입니다.
# 소재가 너무 아깝다.
# 작가는 진지하게 다른 길 찾으시길'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.0308, 부정 확률: 0.9692
#
# --- 예측 결과 ---
# 리뷰: '신이난_침착맨_465784'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '각색 좀 들어갔는데 킬링타임용으론 괜찮은듯.'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.6236, 부정 확률: 0.3764
#
# --- 예측 결과 ---
# 리뷰: '영화의순간들'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '위에서 내려다보지 않고, 가까이에서 눈 맞추는 슈퍼맨의 탄생.'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.5978, 부정 확률: 0.4022
#
# --- 예측 결과 ---
# 리뷰: '호잉이아빠'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '히어로, 그 이상의 인간'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.8597, 부정 확률: 0.1403
#
# --- 예측 결과 ---
# 리뷰: '24fps'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '제임스 건의 좋은 점과 나쁜 점이 혼합됐다. 가오갤스럽지 않은 영화는 찍지 못하게 된건가'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4410, 부정 확률: 0.5590
#
# --- 예측 결과 ---
# 리뷰: '낯선사람'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '진짜 히어로. 이 영화를 기점으로 DC는 영광을 되찾을 것이다.'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.6697, 부정 확률: 0.3303
#
# --- 예측 결과 ---
# 리뷰: '로니'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '우리 곁에도 슈퍼맨이 있다면 얼마나 좋을까.'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.7827, 부정 확률: 0.2173
#
# --- 예측 결과 ---
# 리뷰: 'ossie'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: 'B급 캐릭터를 모아 A급 영화로 만드는 언더독의 재능이, S급 캐릭터를 주인공으로 하는 영화에선 발휘되지 않는 제임스 건의 아픈 손가락 같은 작품.'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4208, 부정 확률: 0.5792
#
# --- 예측 결과 ---
# 리뷰: '작두'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '최고의 시작이라기엔 ‘엥?’스럽지만 훌륭한 영화라는 것에 대해 ‘예스!’라 답할 것이다'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.9779, 부정 확률: 0.0221
#
# --- 예측 결과 ---
# 리뷰: '나릉드르누나'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '와 DC 의 부활인가요!! 가오갤 감독이 만든 DC 영화 성공적!'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.2831, 부정 확률: 0.7169
#
# --- 예측 결과 ---
# 리뷰: '레오'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.5506, 부정 확률: 0.4494
#
# --- 예측 결과 ---
# 리뷰: '제임스 건이 슈퍼맨을 바라보는 가벼운 시선'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.6936, 부정 확률: 0.3064
#
# --- 예측 결과 ---
# 리뷰: '바닐라라떼'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '인간적임을 강조하기 위해 약해져야할 필요가 있을까'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.6142, 부정 확률: 0.3858
#
# --- 예측 결과 ---
# 리뷰: '귀여운_침착맨_569931'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '인간의 무서움을 다 집중하셨으면 좋았을 듯'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.6693, 부정 확률: 0.3307
#
# --- 예측 결과 ---
# 리뷰: '도도한_567681'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '무서움'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.7651, 부정 확률: 0.2349
#
# --- 예측 결과 ---
# 리뷰: '이선빈개미녀'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '보다가 너무 추워져서 죽는 줄 알았어요.
# 보다가 너무 무서워서 눈을 감았더니 놓친 부분들이 있어서 그 부분 보러 또 보러 갈 거예요.'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4800, 부정 확률: 0.5200
#
# --- 예측 결과 ---
# 리뷰: '낯선사람'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '신선함을 주고 싶었던 마음은 알겠으나 한가지에만 집중을 했다면.'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.2415, 부정 확률: 0.7585
#
# --- 예측 결과 ---
# 리뷰: '믹무비'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '사운드가 과하다고 느껴질 때도 있지만, 그만큼 공포감은 충분히 느낄 수 있는 영화!'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.9056, 부정 확률: 0.0944
#
# --- 예측 결과 ---
# 리뷰: '프로무인러'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '소리를 정말 잘 이용한 영화'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.6037, 부정 확률: 0.3963
#
# --- 예측 결과 ---
# 리뷰: '양념반자르반2세'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '롯시 광음시네마관에서 봤는데... 진짜 너무 재밌었습니다. 최근 공포영화들은 너무 식상했는데, 역시 공포영화는 사운드가 중요하니 꼭 극장에서 보시길!'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.8854, 부정 확률: 0.1146
#
# --- 예측 결과 ---
# 리뷰: '만두형제'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '현실적인 층간소음 공포영화. 추천합니다!!'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.9070, 부정 확률: 0.0930
#
# --- 예측 결과 ---
# 리뷰: '친절한_김혜수_298442'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '중반까진 재미있었지만 결말쪽에서 살짝 아쉬웠습니다. 그래도 재미있게 봤습니다'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.8794, 부정 확률: 0.1206
#
# --- 예측 결과 ---
# 리뷰: '작두'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '반전이 드러나며 폭삭 식기는 하지만 공포영화로써 만족도는 상타치'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.6467, 부정 확률: 0.3533
#
# --- 예측 결과 ---
# 리뷰: 'sleepless0401'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '기독교 어린이 교육용 내용이지만 애니메이션의 퀄은 상당하네요'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.2686, 부정 확률: 0.7314
#
# --- 예측 결과 ---
# 리뷰: '방구석11열'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '예수님의 실제 생애 속에서 그분께서 보여주셨던 사랑을 어린 아이들이나 어른들에게 모두 강렬하게 전달하는 마음이 뜨거워지는 영화'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.9586, 부정 확률: 0.0414
#
# --- 예측 결과 ---
# 리뷰: '양기자(YCU)'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '북미에서는 한국을 소재로 한 애니가, 한국에서는 미국 시장을 겨눈 애니가 성공하는 2025년, 흥미롭다. 어린이 여름성경학교 온 느낌.'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4307, 부정 확률: 0.5693
#
# --- 예측 결과 ---
# 리뷰: '가영가'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '한국적 스토리텔링으로 풀어낸 동심적 성경 이야기'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.7212, 부정 확률: 0.2788
#
# --- 예측 결과 ---
# 리뷰: '션스'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '믿음과 기적에 대한 이야기'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.7132, 부정 확률: 0.2868
#
# --- 예측 결과 ---
# 리뷰: '영화조아'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '아무래도 나에겐 이야기가 주는 울림보다 영상미가 더 와닿았던 모양이다'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.6600, 부정 확률: 0.3400
#
# --- 예측 결과 ---
# 리뷰: '키싱구라미'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '병헌리가 들려주는 신선한 웰메이드 기독교 애니메이션'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.9220, 부정 확률: 0.0780
#
# --- 예측 결과 ---
# 리뷰: 'DominickYeo'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '예수님의 생애를 깊고 넓게 그리고 자세하게 보여주며
# 예수님을 모르더라도 모든 사람에게 이 이야기는
# 쉽게 다가간다.'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.7098, 부정 확률: 0.2902
#
# --- 예측 결과 ---
# 리뷰: '상냥한 스필버그_45664'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.5184, 부정 확률: 0.4816
#
# --- 예측 결과 ---
# 리뷰: '정신없고 산만하고 유치하고 억지스럽고
# 게다가 빠순이들의 무지성 별점투척에 신물이난다'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.0226, 부정 확률: 0.9774
#
# --- 예측 결과 ---
# 리뷰: '까칠한 전도연_106912'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.7663, 부정 확률: 0.2337
#
# --- 예측 결과 ---
# 리뷰: '유치하다........'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.0398, 부정 확률: 0.9602
#
# --- 예측 결과 ---
# 리뷰: '신이난_윤여정_539949'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '2000년도에 나왔다고 해도 처참할 정도로 유치찬란함..'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.3691, 부정 확률: 0.6309
#
# --- 예측 결과 ---
# 리뷰: '싹싹한_엠마스톤_754353'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '저 좋은 배우들 가지고, B급 드라마를 만들어 버림.'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.2957, 부정 확률: 0.7043
#
# --- 예측 결과 ---
# 리뷰: '준호_282968'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '작가가 누군지 검색해보게 한거라면 성공한 듯 캐스팅도 영 미스고………..오바액션덩어리'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.2902, 부정 확률: 0.7098
#
# --- 예측 결과 ---
# 리뷰: '드영광'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '아니 그냥 너무 정신없는 드라마예요..
# (그냥 코믹 80퍼, 로맨스 10퍼, 엔딩 때 나오는 약간의 액션 스릴러 10퍼니까 이 점 알고 보시길..)'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.3839, 부정 확률: 0.6161
#
# --- 예측 결과 ---
# 리뷰: '0101010'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '박보검 드라마는 볼게없다 역시나'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.2387, 부정 확률: 0.7613
#
# --- 예측 결과 ---
# 리뷰: '당첨플리즈'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '정의감은 국가대표들만 불타오르나…….. 캐스팅도 좀 안맞고  작가가 라이프온마스 쓴 작가라니……..더 지켜봐야하나 더 보기 힘든데……..'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.2655, 부정 확률: 0.7345
#
# --- 예측 결과 ---
# 리뷰: '드두디'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '별 생각 없이 봤ㄴ는데 샹각보다 엄청 재밌네요'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.9185, 부정 확률: 0.0815
#
# --- 예측 결과 ---
# 리뷰: 'ruru'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '재밌다 1회 엔딩 찢었네 엄청 힘줬다 잘찍었고'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.9551, 부정 확률: 0.0449
#
# --- 예측 결과 ---
# 리뷰: '야생고양이'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '까치와 호랑이 인형이 필요하다.'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.6807, 부정 확률: 0.3193
#
# --- 예측 결과 ---
# 리뷰: '화가난_강동원_590773'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '김구선생님 보고계시나요…
# 소니가 만든 국뽕애니가 넷플공개라니'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.2711, 부정 확률: 0.7289
#
# --- 예측 결과 ---
# 리뷰: '영알못'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: 'K-POP을 제대로 배운 이들이 영리하게 만들어낸 코리엔탈리즘'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.5699, 부정 확률: 0.4301
#
# --- 예측 결과 ---
# 리뷰: '우울한 송강호_138875'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.5031, 부정 확률: 0.4969
#
# --- 예측 결과 ---
# 리뷰: '시즌 2 나왔으면
# 노래도 캐디도 세계관도 너무 잘 뽑힘
# 단발성으로 끝내기엔 넘 아쉽다
# 헌트릭스랑 사자보이즈 나머지 멤버들 과거 이야기도 풀어주길 ㅠ'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.7147, 부정 확률: 0.2853
#
# --- 예측 결과 ---
# 리뷰: '도도한 타란티노_54004'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.6988, 부정 확률: 0.3012
#
# --- 예측 결과 ---
# 리뷰: '예고편만 보고선 또 양놈들이 괴랄한 걸 만들어왔다 싶었는데, 말도 안되게 맛있는 어메리칸 코리안 부대찌개를 만들어 옴. 국내라면 바로 까였을 기획 ㅋㅋㅋㅋ'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.2347, 부정 확률: 0.7653
#
# --- 예측 결과 ---
# 리뷰: '하다니'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.3917, 부정 확률: 0.6083
#
# --- 예측 결과 ---
# 리뷰: '고양이 같은 호랑이 전령 인형 빨리 팔아줘요!'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.6444, 부정 확률: 0.3556
#
# --- 예측 결과 ---
# 리뷰: 'PHY'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '이게 왜.... 재밌지?'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4538, 부정 확률: 0.5462
#
# --- 예측 결과 ---
# 리뷰: '궁금한_팀버튼_625622'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '안효섭이 한국어로 이만큼만 연기해도 진짜  좋겠다. 안효섭의 재발견'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.7539, 부정 확률: 0.2461
#
# --- 예측 결과 ---
# 리뷰: '귀여운_침착맨_569931'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '귀에 쏙쏙 들어오는거 인정 ㄹㅎㅎㅎ'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.5690, 부정 확률: 0.4310
#
# --- 예측 결과 ---
# 리뷰: '상냥한_에스파_674217'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '왜 재밌는지 의문이 들지만 재미있음ㅋㅋㅋㅋㅋ'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.7435, 부정 확률: 0.2565
#
# --- 예측 결과 ---
# 리뷰: '귀여운_침착맨_569931'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '이걸 안본 사람이
# 승리자'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.1827, 부정 확률: 0.8173
#
# --- 예측 결과 ---
# 리뷰: '도도한 스필버그_54099'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.5184, 부정 확률: 0.4816
#
# --- 예측 결과 ---
# 리뷰: '올해 극장에서 본 최악의 영화
# 약 먹고 시나리오쓴거 같다.
# 연출도 학생이 한거 같다.'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.0459, 부정 확률: 0.9541
#
# --- 예측 결과 ---
# 리뷰: '도도한_아이유_894875'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '노이즈보다 열배 재미'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.3927, 부정 확률: 0.6073
#
# --- 예측 결과 ---
# 리뷰: '로니'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '창의력은 전혀 없고 그저 진부하고 구리다.'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.0223, 부정 확률: 0.9777
#
# --- 예측 결과 ---
# 리뷰: 'Voyant'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '공포영화에서 유치함을 느끼는건 너무나 치명타다.
# 그것도 어의없게도 대사와 연기연출 부분에서'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.3443, 부정 확률: 0.6557
#
# --- 예측 결과 ---
# 리뷰: '낯선사람'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '한국영화가 왜 망해가고 있는지 보여준다.'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4514, 부정 확률: 0.5486
#
# --- 예측 결과 ---
# 리뷰: '마뮤렌'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '터를 잘 잡아야한다는 옛말이 틀리지 않았다'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.3723, 부정 확률: 0.6277
#
# --- 예측 결과 ---
# 리뷰: '해바라기'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.3670, 부정 확률: 0.6330
#
# --- 예측 결과 ---
# 리뷰: '빨간불 10% 받을 영화는 아니라고 생각되는 영화다 노이즈보단 잘 만들었다.'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.7060, 부정 확률: 0.2940
#
# --- 예측 결과 ---
# 리뷰: '상추재배'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '이미 우리나라에 이런 영화가 많이 있고 심지어 재미도 없는데 왜 똑같은게 계속 생산될까. 하나의 컨셉을 가지지 않고 재밌을 것 같은거는 다 끼워놓고 뭐 하나 걸려라는 이제 안통한다'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4666, 부정 확률: 0.5334
#
# --- 예측 결과 ---
# 리뷰: '지누씨네'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '다각도로 두드리는 시도,
# 언젠간 문이 열릴 것이다
# (1분 쇼츠 올림)'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4958, 부정 확률: 0.5042
#
# --- 예측 결과 ---
# 리뷰: '하다니'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.3917, 부정 확률: 0.6083
#
# --- 예측 결과 ---
# 리뷰: '매번 드라마의 주인공이었던 개업변호사나 대형로펌의 고용변이 아닌 직업인으로서의 고용변의 모습을 잘 보여주고 있다
# 비현실적으로 잘생기고 이쁜 변호사들이지만 그걸 욕할 수는 없지'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.6620, 부정 확률: 0.3380
#
# --- 예측 결과 ---
# 리뷰: '작두'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '언젠가는 재미있을 <서초동>생활'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.6330, 부정 확률: 0.3670
#
# --- 예측 결과 ---
# 리뷰: '친절한_강동원_724065'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '변호사들도 보통의 직장인이라는 컨셉을 가져가려는 듯 한데.. 이종석의 스타일링이 너무 왕자님이다.'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.3730, 부정 확률: 0.6270
#
# --- 예측 결과 ---
# 리뷰: 'ruru'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '사건이랑 럽라가 재밌음'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.9863, 부정 확률: 0.0137
#
# --- 예측 결과 ---
# 리뷰: '앙'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '일단 현실에 맞개 좀 인물이 펑범했으먼 좋겠음 죄다 잘생기고 맛있음 젊고 좀더 나이든나이가 있는 ㅜ ㅣㅗ'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.5243, 부정 확률: 0.4757
#
# --- 예측 결과 ---
# 리뷰: '즐거운_이병헌_516323'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '매회 법률관련 에피소드와 이종석,문가영 로맨스가 기대됩니다.'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.8740, 부정 확률: 0.1260
#
# --- 예측 결과 ---
# 리뷰: '귀여운 마고로비_134474'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.8759, 부정 확률: 0.1241
#
# --- 예측 결과 ---
# 리뷰: '오랜만에 이종석 복귀작 슴슴한 평양냉면 같은데 은근히 끌린다고 해야되나? 의외로 흥미가 생기는 러브라인
# 현실에 맞닿은 이야기로 잘 풀어줬으면'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.7378, 부정 확률: 0.2622
#
# --- 예측 결과 ---
# 리뷰: '무하마드찰리'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '식당에서 밥 먹다가 공익에 대해서 설전을 벌이는 장면. 아 이런 거 이제 좀 안하면 안되나'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.3919, 부정 확률: 0.6081
#
# --- 예측 결과 ---
# 리뷰: '3점폭격기'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '현실적이라 재밌어보임 넷플에서도 볼 수 있음 좋겠다...'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.7618, 부정 확률: 0.2382
#
# --- 예측 결과 ---
# 리뷰: 'LAON'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '너무 재미있게 봤던 알라딘!  영상미도 훌륭하고 배우들연기 갓벽하고 음악들도 너무 좋았다 더군다나 지니는 진짜완벽했다👍'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.9695, 부정 확률: 0.0305
#
# --- 예측 결과 ---
# 리뷰: '사과'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4757, 부정 확률: 0.5243
#
# --- 예측 결과 ---
# 리뷰: '영화 <알라딘>을 봤다. 처음봤을때, 외국인 관크를 당해서 본건지 안본건지 싶었으나 물리적인 시간정황상 봤기 때문에 할말이 없구나 하고 자파가 제일 잘생겼고, 앵무새 이아고가 제일...'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.2882, 부정 확률: 0.7118
#
# --- 예측 결과 ---
# 리뷰: '보문동꿀주먹'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '캐스팅 좋고~ 노래도 좋지만~ 제발 원작을 비트는 건 적당히 해줘!'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.3442, 부정 확률: 0.6558
#
# --- 예측 결과 ---
# 리뷰: '서현'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '진짜 완전 인생작..'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.6603, 부정 확률: 0.3397
#
# --- 예측 결과 ---
# 리뷰: '행복'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.7270, 부정 확률: 0.2730
#
# --- 예측 결과 ---
# 리뷰: '지금까지도 잊혀지지 않는 ost들..!!
# 한때 인생작이었던 만큼 명작입니다'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.9646, 부정 확률: 0.0354
#
# --- 예측 결과 ---
# 리뷰: '프로무인러'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '실사화를 정말 잘했다고 생각하는 작품...'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.7463, 부정 확률: 0.2537
#
# --- 예측 결과 ---
# 리뷰: '톰홀랜드'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '어떻게 이렇게 캐스팅을 잘해...? 지금과 비교되는 재미와 완성도 캐스팅..'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.5496, 부정 확률: 0.4504
#
# --- 예측 결과 ---
# 리뷰: '이오더매드문'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '한줄평
# - 싱잉랩도 잘하는 윌 스미스'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.3326, 부정 확률: 0.6674
#
# --- 예측 결과 ---
# 리뷰: '박성현'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '디즈니 고전 애니메이션의 실사는 항상 원작에서 따온 부분과 그렇지 않은 부분의 위화감이 문제가 된다. 알라딘도 그런 면에서 피해갈 순 없었지만 그래도 윌 스미스의 지니와 나오미 스...'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.5978, 부정 확률: 0.4022
#
# --- 예측 결과 ---
# 리뷰: '쀼쇼숑'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '디즈니가 이렇게만 계속 만들면 좋겠음
# 너무 좋은 실사화임'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.7179, 부정 확률: 0.2821
#
# --- 예측 결과 ---
# 리뷰: '귀여운_침착맨_569931'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '지루한 서사와 적은 공룡 등장씬 ㄷㄷ 넘해요'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.2098, 부정 확률: 0.7902
#
# --- 예측 결과 ---
# 리뷰: 'chance'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '더 이상 보여줄 게 없어서 그런지 갈수록 괴기해지는 공룡이 안쓰럽다'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.2410, 부정 확률: 0.7590
#
# --- 예측 결과 ---
# 리뷰: '낯선사람'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '뻔하고 진부한 스토리, 쓸데없이 길다.'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.0181, 부정 확률: 0.9819
#
# --- 예측 결과 ---
# 리뷰: '자연형인간'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: ''놀이공원에 있는 공룡태마파크 vlog 영상과 동등한 영화''
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.7887, 부정 확률: 0.2113
#
# --- 예측 결과 ---
# 리뷰: '키다리노진구'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '나는 공룡영화 처음 봐서 재미있었다 ..'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.8022, 부정 확률: 0.1978
#
# --- 예측 결과 ---
# 리뷰: '키높이오'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '더 이상 새롭지 않은 공룡. 어디까지 새로워지나 보자.'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.3624, 부정 확률: 0.6376
#
# --- 예측 결과 ---
# 리뷰: '미친나미나'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '정상인 없음. 공룡도 너무 멍청하고 답답함. 긴장감도 없고 에초에 죽는사람도 별로 없음. 그리고 스칼렛요한슨은 이제 스칼렛요한슨 역에서 좀 벗어나주세요.'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.0166, 부정 확률: 0.9834
#
# --- 예측 결과 ---
# 리뷰: '상냥한_김선호_290404'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '초반 전개가 매우 늘어지고
# 내용이 진부하다'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.0791, 부정 확률: 0.9209
#
# --- 예측 결과 ---
# 리뷰: '놀슈'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '쥬월 시리즈 중에 가장 쥬공에 가까운 영화.
# 그래서 가장 나았지만 너무 슴슴해서 아쉬웠다.'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.7954, 부정 확률: 0.2046
#
# --- 예측 결과 ---
# 리뷰: '도도한_567681'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '너무 지루하다
# 긴장감은 하나도 없고 다큐 같다
# 시간 아깝다
# 새로운 시작을 하지 말지 왜 했을까'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.0062, 부정 확률: 0.9938
#
# --- 예측 결과 ---
# 리뷰: '귀여운_침착맨_569931'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '레전드 재부활 진짜 재미있었습니다 ㅎㅎㅎ'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.9528, 부정 확률: 0.0472
#
# --- 예측 결과 ---
# 리뷰: '만두'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '어릴 때는 무섭기만 했지만 계속 보다보니 재밌음'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.9121, 부정 확률: 0.0879
#
# --- 예측 결과 ---
# 리뷰: '티누비엘'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '22년의 시간을 뛰어넘어 다시 돌아온 시리즈는 기술의 발전에 힘입어 놀라운 액션과 스릴을 보여주며 SF의 대표작으로 꼽히는 프랜차이즈의 기존 색채는 옅어지고 오히려 괴수재난영화 같...'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.7058, 부정 확률: 0.2942
#
# --- 예측 결과 ---
# 리뷰: '톰홀랜드'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '쥬라기도 세대교체'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '친절한_브래드피트'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '공룡 좋아하는 아이 덕에 하도 많이 봐서 다 외울 지경입니다 ㅋㅋ 강추에요!!'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.5967, 부정 확률: 0.4033
#
# --- 예측 결과 ---
# 리뷰: '박성현'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '쥬라기 월드는 이전 쥬라기 공원 시리즈 영화들과 개장하여 사람들이 들어찬 공원에서 공룡들이 소동을 벌인다는 점이 가장 큰 차이다. 그런 차이를 이용하여 공룡들이 관람객을 습격하는등...'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.5401, 부정 확률: 0.4599
#
# --- 예측 결과 ---
# 리뷰: 'ottliker'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '가장 따뜻한 렙터, 블루.'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.8980, 부정 확률: 0.1020
#
# --- 예측 결과 ---
# 리뷰: '낯선사람'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '인간의 공룡 길들이기.'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.7242, 부정 확률: 0.2758
#
# --- 예측 결과 ---
# 리뷰: '양기자(YCU)'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '<쥬라기 공원> 이후 20년 후에 진정한 속편은 나라고 외치는 소리가 들려온다.'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4925, 부정 확률: 0.5075
#
# --- 예측 결과 ---
# 리뷰: 'SH60243'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '이때 박수받으면서 퇴장했어야했어...'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.7151, 부정 확률: 0.2849
#
# --- 예측 결과 ---
# 리뷰: '마니아와'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '다가오는 7월 개봉이던데 좀 불안불안해서 기대반 걱정반이다..'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.7733, 부정 확률: 0.2267
#
# --- 예측 결과 ---
# 리뷰: '싹싹한_김남길_981549'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '웹툰 요소가 잘 반영되었네요. 시나리오, 배우 연기,  CG 다 완성도 높고 재밌습니다!'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.7664, 부정 확률: 0.2336
#
# --- 예측 결과 ---
# 리뷰: '로이로이'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '내가 소설 속 주인공이 된다? 예고편만으로도 몰입감 미쳤다'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.6447, 부정 확률: 0.3553
#
# --- 예측 결과 ---
# 리뷰: '레모네이드'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: ''신과 함께' 제작진 + 300억 스케일 벌써부터 기대되는 한국형 판타지'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4797, 부정 확률: 0.5203
#
# --- 예측 결과 ---
# 리뷰: '아무말잔치'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '안효섭의 ‘김독자’는 어떨지 원작 팬으로서 가장 기대되는 순간'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.7697, 부정 확률: 0.2303
#
# --- 예측 결과 ---
# 리뷰: '폭룡적_김남길_740657'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '영활 보고 난 뒤 든 생각. 만약 4년전 제대로 개봉 될 수 있었 다면    지금 보다 훨씬 더 미친 반응을 이끌었을 지도 모를...'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.6338, 부정 확률: 0.3662
#
# --- 예측 결과 ---
# 리뷰: '힙합팬'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '한국영화에선 보기 힘든 장면들이 수두룩한 귀한 영화.'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4078, 부정 확률: 0.5922
#
# --- 예측 결과 ---
# 리뷰: '귀여운_침착맨_569931'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '딱 써니 감독스란 감독스런 그런 스타일 진행영화'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.5691, 부정 확률: 0.4309
#
# --- 예측 결과 ---
# 리뷰: '마뮤렌'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '유치뽕짝한게 아기자기한 재미가 있다. 물 많이 마시고 서로 도우면서 삽시다. 유X인이 나오니까 분위기가 확 달라지는게 재능이 넘치는데 왜 그랬는지 참...'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.7073, 부정 확률: 0.2927
#
# --- 예측 결과 ---
# 리뷰: '돈패닉'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '구걸! 프레쉬걸! 빳데리맨! 탱크보이! 블루스맨!
# 초능력 합진이다!'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.5847, 부정 확률: 0.4153
#
# --- 예측 결과 ---
# 리뷰: '퐝군'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '기대를 안하고 봐서 그런지 생각보다 많이 웃으면서 본 한국형 히어로 팝콘 무비임.'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4705, 부정 확률: 0.5295
#
# --- 예측 결과 ---
# 리뷰: '침착한_김선호_524239'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '강형철 감독은 아직 2010년대 감성에서 못헤어나오는 듯'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.1788, 부정 확률: 0.8212
#
# --- 예측 결과 ---
# 리뷰: '레오'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.5506, 부정 확률: 0.4494
#
# --- 예측 결과 ---
# 리뷰: '오랜만에 나온 가족끼리 보기 좋은 영화 기대됩니다!'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.9472, 부정 확률: 0.0528
#
# --- 예측 결과 ---
# 리뷰: '도도한_567681'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '후기'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.3415, 부정 확률: 0.6585
#
# --- 예측 결과 ---
# 리뷰: '똑똑한_전지현_514616'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '시사회로 봤눈데 킬링타임 영화로 좋아요 재밌어ㅅㅇ'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.9006, 부정 확률: 0.0994
#
# --- 예측 결과 ---
# 리뷰: '아직 작성된 리뷰가 없어요'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.3248, 부정 확률: 0.6752
#
# --- 예측 결과 ---
# 리뷰: 'Movie_changgo_'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '드림윅스에서 가장 명작 시리즈라고 생각한다.'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.9662, 부정 확률: 0.0338
#
# --- 예측 결과 ---
# 리뷰: '귀여운_침착맨_569931'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '애니는 역시 실사보단 이거지'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.7290, 부정 확률: 0.2710
#
# --- 예측 결과 ---
# 리뷰: '필름 판타지아'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.2653, 부정 확률: 0.7347
#
# --- 예측 결과 ---
# 리뷰: '해충에서 동반자가 되기까지. 인간이든 드래곤이든, ‘잘못 안다’는 것이 얼마나 어리석은 일인지!'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.3674, 부정 확률: 0.6326
#
# --- 예측 결과 ---
# 리뷰: '천아손'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '아이들 영어공부땜에 같이 봤던 영화 원작소설도 있어서 줄거리도 탄탄하고 작품성도 있어요 가족이 모두 함께 보면 좋아요!'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.9818, 부정 확률: 0.0182
#
# --- 예측 결과 ---
# 리뷰: '영화계피카소'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '나도 드래곤 가지고싶다.'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.6091, 부정 확률: 0.3909
#
# --- 예측 결과 ---
# 리뷰: '요키치'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '비행 장면의 쾌감만은 제대로 느꼈다. 나이가 먹을수록 애니메이션을 더 까다롭게 보는 것 같다...'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.6478, 부정 확률: 0.3522
#
# --- 예측 결과 ---
# 리뷰: '김민지'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '아 실사화가 아니라 애니메이션이었네요~~ 예전에 봤던거라 기억이 잘 안났는데 오랜만에 실사화 보니 새록새록 기억이 나더라구요 넘 재밌었습니다!!'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.9391, 부정 확률: 0.0609
#
# --- 예측 결과 ---
# 리뷰: '라둡네'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '순위거 왜이래?'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4587, 부정 확률: 0.5413
#
# --- 예측 결과 ---
# 리뷰: 'movie__again'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '서로에게 남긴 상처는 서로를 이해함으로써 비로소 흉터가 된다.'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.8347, 부정 확률: 0.1653
#
# --- 예측 결과 ---
# 리뷰: '즐거운_강동원_723654'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '이게 실사화지 너무 재밌고 캐릭들 다 찰떡인대 내용도 원작그대로 실사를 잘옮겨놔서 원작보다 스케일커짐 돌비로 봤는대 음악도 계속 웅장해서 너무 재밌었다'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.9124, 부정 확률: 0.0876
#
# --- 예측 결과 ---
# 리뷰: '마뮤렌'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '거북목 있는지 목 쭉 빼고 문 앞에 서있던 학생이 너무 무섭다 했는데...'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.3722, 부정 확률: 0.6278
#
# --- 예측 결과 ---
# 리뷰: '팜므파탈캣'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '변태성욕자를 처단하는 소녀여 건승!
# 200406'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '회사인시우'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '비를 피하기 위해 들어간 곳은 어디일까'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4789, 부정 확률: 0.5211
#
# --- 예측 결과 ---
# 리뷰: 'BIGMAC_bro'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '단편치고는 의외의 긴장감과 스릴감'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.8118, 부정 확률: 0.1882
#
# --- 예측 결과 ---
# 리뷰: 'KillerWhale'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '연기력이 어설프다'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.0966, 부정 확률: 0.9034
#
# --- 예측 결과 ---
# 리뷰: '비니비니'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '장마를 피해 들어간 곳은 어디일까'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4047, 부정 확률: 0.5953
#
# --- 예측 결과 ---
# 리뷰: '순영이'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '100일 사귄사람이 메기인게 개웃기넼ㅋㅋㅋㅋ'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '톰홀랜드'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '싸움구경하는듯 보게되는 스우파2'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.7123, 부정 확률: 0.2877
#
# --- 예측 결과 ---
# 리뷰: '봄봄.'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '다들 춤을 잘춰서 볼맛남 바다웅니 짱🔅'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.5038, 부정 확률: 0.4962
#
# --- 예측 결과 ---
# 리뷰: '민주돌이'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '스우파1보다 낫네요 바다가 짱인듯'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.7867, 부정 확률: 0.2133
#
# --- 예측 결과 ---
# 리뷰: '생귤탱귤귤'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '역시나 본방사수하게 만드는 프로그램'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.1844, 부정 확률: 0.8156
#
# --- 예측 결과 ---
# 리뷰: '온리샨'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '재밋어여'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.7786, 부정 확률: 0.2214
#
# --- 예측 결과 ---
# 리뷰: 'JAYU'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '스우파2를 보자마자 커스틴퀸을 경배하게 되었지만 그녀가 인정한 리얼월드와이드배틀러인 마네퀸쌤들(왁씨 윤지 쎄라)을 인정하지 않을 수가 없음 이분들이 한국댄서인게 자랑스럽다'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.6862, 부정 확률: 0.3138
#
# --- 예측 결과 ---
# 리뷰: '찐더쿠'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '바다'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.3779, 부정 확률: 0.6221
#
# --- 예측 결과 ---
# 리뷰: '고앵씨'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '스우파 1 만큼 모든이들이 돋보이는 방송이 되지못한건 아이키같은 캐릭터가 없어서일까 아이키가 없어서일까. 시작전부터 바다만 보였는데 역시다. 승승장구해라'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.7953, 부정 확률: 0.2047
#
# --- 예측 결과 ---
# 리뷰: '폭룡적_카리나_812159'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '너무 길고 길어서 좀 지루한 경향이 있어 뒤로갈수록 안보게됨 시즌1의 성공을 알기에 모두 순한맛 변신, 추후 3가 나온다면 볼 것 같지않음'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.2449, 부정 확률: 0.7551
#
# --- 예측 결과 ---
# 리뷰: '클로버'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '최고였다. 모든 팀들이 너무 멋있었고 특히 미션 하나하나 각 팀들이 발휘된 느낌이라 볼 때마다 감탄했다'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.9196, 부정 확률: 0.0804
#
# --- 예측 결과 ---
# 리뷰: '작두'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '<폭싹 속았수다>에 이은 올해 최고의 드라마가 되었다'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.8750, 부정 확률: 0.1250
#
# --- 예측 결과 ---
# 리뷰: '0101010'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '노잼인데 바이럴이 심한듯'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.2213, 부정 확률: 0.7787
#
# --- 예측 결과 ---
# 리뷰: '연분홍빛춤출무렵'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '박보영의 1인 2역이 아니라 제곱승역이다. 1인 2역을 하면서 성격이 다른  부분을 연기하며 2의제곱승 사실상 4역 거기서 더 파생될 역들은 기하급수적이다. 잘하면 인생작 만나겠다'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.5789, 부정 확률: 0.4211
#
# --- 예측 결과 ---
# 리뷰: '귀여운_침착맨_569931'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '박보영의 매력은 이런 매력이지'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.3009, 부정 확률: 0.6991
#
# --- 예측 결과 ---
# 리뷰: '머틀도사'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '1인 4역 대박! 모든 상처받은 사람에게 주는 잔잔한 위로.
# "내가 아니랬자나" 열기 장인 미지의 모든 닫힘은 미지 스스로가 닫은 거였다. 우리 인생도 아마도.'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.9034, 부정 확률: 0.0966
#
# --- 예측 결과 ---
# 리뷰: '창원전지현🫰🏻'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '서울쥐와 시골쥨ㅋㅋㅋᩚㅋᩚㅋᩚ  인간편'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '도도한_567681'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '너무 슬프다'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.8600, 부정 확률: 0.1400
#
# --- 예측 결과 ---
# 리뷰: '하다니'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.3917, 부정 확률: 0.6083
#
# --- 예측 결과 ---
# 리뷰: '좋다
# 박보영 역시 걸출한 배우이다
# 박보영으로는 뭔 작품을 갖다놔도 실패하지 않을 느낌
# 하지만 극본은 글쎄. 속았수다에 비할 바는 아닌 둣
# +볼수록 실망. 전개속도를 2배로 높여야'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.5283, 부정 확률: 0.4717
#
# --- 예측 결과 ---
# 리뷰: '조선팔도제일한량012'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '박보영의 연기 차력쇼'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.7222, 부정 확률: 0.2778
#
# --- 예측 결과 ---
# 리뷰: '레오'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.5506, 부정 확률: 0.4494
#
# --- 예측 결과 ---
# 리뷰: '재밌어요'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.9803, 부정 확률: 0.0197
#
# --- 예측 결과 ---
# 리뷰: '도도한_서강준_911721'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '재미있겄다'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '박보노'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '불륜, 재벌, 정계싸움 등 자극적인 영화와 드라마들 사이에서 피어난 한송이의 들꽃.. 너무 오랜만에 내 취향'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.5751, 부정 확률: 0.4249
#
# --- 예측 결과 ---
# 리뷰: '낙관주의민'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '남녀 모두 엄청난 서사를 갖고 있지만  생의 의미는 그냥 최선을 다하는 것. 언제 떠나더라도 미련은 가능한 최소화하고 사랑하는 사람이 웃을 수 있는 추억을 만들어주는 것 ♡'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.8035, 부정 확률: 0.1965
#
# --- 예측 결과 ---
# 리뷰: '친절한_짱구_536087'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '애매~~~함. 일단 전여빈의 외모가 너무 평범하구, 연기도.. 다소 오바스럽고 오글거린달까. 극본은 무난한데 캐스팅이 아쉬움. 비타민씨 같은 여배우가 맡았더라면 더 몰입했을 텐데.'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4458, 부정 확률: 0.5542
#
# --- 예측 결과 ---
# 리뷰: '너무많이봐서기억도안나'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '전여빈 목소리왜줘랩.. 빈센조에서의 목소리랑 다르자나
# 드라마속의 영화대사는 왜케 오글거랴'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.3295, 부정 확률: 0.6705
#
# --- 예측 결과 ---
# 리뷰: '퇴근하고드라마봐야지'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '편안해요,'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '닉네임'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '얼굴을 마주하고 대화하는 scene 위주인데 점점 더 재밌어진다. 진부한 내용일 줄 알았는데 유일한 영화를 만드는 배우들.'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.1984, 부정 확률: 0.8016
#
# --- 예측 결과 ---
# 리뷰: '천아손'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '잔잔래서 몰입감이 떨어진다고들 하지만 , 그래도 전 재미있게 보고 있아요 전여빈 이설 배우 늘 응원합니다!'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.9493, 부정 확률: 0.0507
#
# --- 예측 결과 ---
# 리뷰: '김민지'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '시사회 통해서 봤어요!! 1화에사 2화로 넘어갈 때 눈물이 펑펑 ㅠㅠ 오늘 3화도 본방사수 했네요!! 앞으로의 내용들이 더 기대돼요 ㅎㅎ 더 많은 내용은 블로그 참고해주세요!'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.9520, 부정 확률: 0.0480
#
# --- 예측 결과 ---
# 리뷰: '마르코'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '기대이상이네요'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '시즈씨'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '영화에 대한 동경은 드라마의 한계에 갇히고, 시한부 멜로의 파격은 감정의 초점 밖에 머문 ‘남의 영화’.'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4367, 부정 확률: 0.5633
#
# --- 예측 결과 ---
# 리뷰: '드영광'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '시즌 1만 본 사람이 이 게임의 우승자'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.7020, 부정 확률: 0.2980
#
# --- 예측 결과 ---
# 리뷰: '상냥한_안나_234193'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '저만 재밌었나요..?'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.2947, 부정 확률: 0.7053
#
# --- 예측 결과 ---
# 리뷰: '낯선사람'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '이전 2개의 시즌을 보면서 느꼈던 ‘벌써 끝이야?’ 라는 생각은 들지않고 ’언제 끝나지?‘ 라고 생각하는 나를 발견했다.'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.6553, 부정 확률: 0.3447
#
# --- 예측 결과 ---
# 리뷰: '샤베트'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '시즌2부터 쌔함의 징조는 있었지만 이정도로 역대급 졸작일줄은.. 캐릭터 소모도 멋대로에 스토리도 말아먹고 또 다시 후속작얘기를 할줄이야 ㅋㅋ 진짜 다신 보지말자'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.6086, 부정 확률: 0.3914
#
# --- 예측 결과 ---
# 리뷰: '작두'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '시즌2에서 봉합되지 못한 것들이 여전히 봉합되지 못하고, 신파만 남발하다 희생정신을 강요하는 듯 불필요한 시즌임이 틀림없다'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.2086, 부정 확률: 0.7914
#
# --- 예측 결과 ---
# 리뷰: '도도한_567681'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '너무 지루하다'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.0164, 부정 확률: 0.9836
#
# --- 예측 결과 ---
# 리뷰: '궁금한_팀버튼_625622'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '재밌구만. 이미 시즌 종료된 걸 이렇게 멱살잡고 끌고온 것도 대단한거임. 1시즌으로 돈 못 번 황동혁 감독 이거로 돈 벌었음 충분하다고 본다.'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.6275, 부정 확률: 0.3725
#
# --- 예측 결과 ---
# 리뷰: '카즈하'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '결말이 어떻고 간에 중간에 외국 VIP들 때문에 몰입도 ㅈㄴ 방해되네'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.2588, 부정 확률: 0.7412
#
# --- 예측 결과 ---
# 리뷰: '덤덤한_윤여정_163280'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '너 고구마 좋아하잖아'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: 'GTOPVC'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '4화 진짜 장난하나ㅋㅋㅋㅋㅋㅋㅋ 작가들 한 화씩만 맡았음? 개연성 너무 떨어짐'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.0709, 부정 확률: 0.9291
#
# --- 예측 결과 ---
# 리뷰: '키노마크'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '7월 11일 금요일 저녁 8시 40분 이번에는 복싱이다'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4574, 부정 확률: 0.5426
#
# --- 예측 결과 ---
# 리뷰: '행복회로'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '박주현 여주 연기가  늘지 않아 아쉬움'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.5906, 부정 확률: 0.4094
#
# --- 예측 결과 ---
# 리뷰: '아미가로'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '남주 여주 연기가...집중을 방해 한다...'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.3671, 부정 확률: 0.6329
#
# --- 예측 결과 ---
# 리뷰: '무하마드찰리'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '살인마, 프로파일러에 열광하는 나라에서 왜 이리 범죄스릴러는 제대로 된 게 안 나올까'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.3436, 부정 확률: 0.6564
#
# --- 예측 결과 ---
# 리뷰: '사이렌오빠'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '박주현 연기 보기 힘드네 ㅜㅜ'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.3375, 부정 확률: 0.6625
#
# --- 예측 결과 ---
# 리뷰: '낯선사람'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '죄책감을 정의로 승화시킨다.'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: 'Cona'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '먼가 조금 아쉬움이 남긴 한대 재미 있게 좔봄'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.6642, 부정 확률: 0.3358
#
# --- 예측 결과 ---
# 리뷰: 'jihux'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '🥰'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '너무많이봐서기억도안나'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '여주연기왜그럴까.. 이런거보면 범인들 참 부지런해'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.3882, 부정 확률: 0.6118
#
# --- 예측 결과 ---
# 리뷰: 'Qikachu'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '8~10부작짜리를 16부로 늘려놓은 느낌 중간에 상당히 지루함 후반부가 볼만했고 괜찮은 엔딩인줄 알았으나 난데없는 오글오글씬으로 끝을 내는 바람에 엥 소리 절로 나옴'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.1597, 부정 확률: 0.8403
#
# --- 예측 결과 ---
# 리뷰: '그림소리'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '지극히 자극적인 소재에 비해 그냥저냥 심심한 결과물이 될 뻔했으나, 빠른 전개와 중후반의 흡입력으로 뚝심 있게 밀어붙인다.'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.2443, 부정 확률: 0.7557
#
# --- 예측 결과 ---
# 리뷰: '쵸파'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '간만에 추리가 메인인 극장판이라 재밌었음! 전작 펜타그램보다는 200배 낫다. 특유의 현실성없는 연출도 있지만 봐줄만할정도. 공안, 나가노현경등 배경을 알아야 이해가능하다...'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.7661, 부정 확률: 0.2339
#
# --- 예측 결과 ---
# 리뷰: '작은제비'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '추리요소를 많이 집어넣어서 스토리에 몰입되었고 액션은 살짝 과하다는 생각이 들긴하나 영화에 재미를 더했다는 생각이든다'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4795, 부정 확률: 0.5205
#
# --- 예측 결과 ---
# 리뷰: '양기자(YCU)'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '한 작품 정도는 주인공을 줘도 될 것 같았는데, 드디어.'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.6039, 부정 확률: 0.3961
#
# --- 예측 결과 ---
# 리뷰: '소나'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.3044, 부정 확률: 0.6956
#
# --- 예측 결과 ---
# 리뷰: '고쇼작가님이 드디어 관객을 끌어당기는 법을 안 것 같다'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4336, 부정 확률: 0.5664
#
# --- 예측 결과 ---
# 리뷰: '24fps'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '시청층을 높였는데 아이 관객도 포기못해서 생긴 불협화음'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.2831, 부정 확률: 0.7169
#
# --- 예측 결과 ---
# 리뷰: 'Veil'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '이 시대에 태어난 이유는 진격의 거인을 보기 위해서였다.'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.3498, 부정 확률: 0.6502
#
# --- 예측 결과 ---
# 리뷰: '영린이'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '마지막을 향한 땅울림'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.6465, 부정 확률: 0.3535
#
# --- 예측 결과 ---
# 리뷰: '인생영화찾는사람'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '진짜 연출이 지리는데'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4191, 부정 확률: 0.5809
#
# --- 예측 결과 ---
# 리뷰: '왕순kim'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '끝을 향해 달려가는 진격의 거인.'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.3359, 부정 확률: 0.6641
#
# --- 예측 결과 ---
# 리뷰: 'MOVIE1221'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '멸망을 초래할 재앙의 공포 속에서 일치해가는 후회와 죄책감, 잔혹한 세계 속에서 찾고 싶은 희망'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.8669, 부정 확률: 0.1331
#
# --- 예측 결과 ---
# 리뷰: 'SH60243'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: 'GOAT'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: 'PHY'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '애니가 아니다. 역사다.'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.2729, 부정 확률: 0.7271
#
# --- 예측 결과 ---
# 리뷰: '상냥한_신동엽_548064'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '시리즈의 빈곳을 다듬기 위한 사포.'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.3618, 부정 확률: 0.6382
#
# --- 예측 결과 ---
# 리뷰: '도전정신'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '떡밥 회수의 교과서. 최근 중에 가장 도파민 터지는 느낌.. 오랜만이었음'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.8191, 부정 확률: 0.1809
#
# --- 예측 결과 ---
# 리뷰: '그림소리'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '파멸의 신화가 촘촘하게 결말로 향한다.'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4731, 부정 확률: 0.5269
#
# --- 예측 결과 ---
# 리뷰: '쿠곰라이츠'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '한국 웹툰으로 가장 성공적인 애니메이션'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.8029, 부정 확률: 0.1971
#
# --- 예측 결과 ---
# 리뷰: '귀여운_침착맨_569931'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '성진우!! 진격의 거인이후로 잘 챙겨 보는 애니!!!!!'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4534, 부정 확률: 0.5466
#
# --- 예측 결과 ---
# 리뷰: 'L͜͡o͜F͜i'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '원작에 충실하고 작화를 갈아넣은 액션씬이 돋보인다. 한국작품 애니화될때 저퀄인 경우가 대부분이었는데 힘 많이 줬다. 캐릭터 한국어이름, 일어이름 이중녹음하는 성의도 보였다'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4919, 부정 확률: 0.5081
#
# --- 예측 결과 ---
# 리뷰: '메키케키'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '이 정도면 웹툰을 애니로 적당히 잘 바꾼 듯'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.3672, 부정 확률: 0.6328
#
# --- 예측 결과 ---
# 리뷰: 'dotlgn_anime'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '아직 방영중이지만 전개를 너무 질질 끈다...'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.1605, 부정 확률: 0.8395
#
# --- 예측 결과 ---
# 리뷰: '프리렌'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '소설 웹툰 다 안봤는데
# 이거 보고 왜 안봤었을까 후회중
# 너무 재밌음'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.7046, 부정 확률: 0.2954
#
# --- 예측 결과 ---
# 리뷰: '아휴참'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '한국어 더빙 원해요??'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.2809, 부정 확률: 0.7191
#
# --- 예측 결과 ---
# 리뷰: '네오바나나'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '에반게리온과 고질라, MMOGPG의 소재와 장점을 잘 접목해서 마치 게임을 하듯이 스토리에 녹여낸 신박함에 빠져드게 만드네요.
# 아주 나약한 주인공이 점차 성장하는데 기대와 궁금!'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.1930, 부정 확률: 0.8070
#
# --- 예측 결과 ---
# 리뷰: '딤'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '친구 추천으로 봣는데 짱 재밋습니다…. 취저..💓'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.7272, 부정 확률: 0.2728
#
# --- 예측 결과 ---
# 리뷰: '마요케찹'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '일본판 이름으로 창씨개명 안당하고 기무상, 바꾸상 이러는 거 보기 좋음. 대신 좀 질질 끌어서 노잼'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.2233, 부정 확률: 0.7767
#
# --- 예측 결과 ---
# 리뷰: '화가난_차은우_630687'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '팬들을  생각하는  마음이 진심이라는걸 다시 한번  느끼고 감동 받았어요~ 지금도  좋은 점이   차고 넘치는데  더 좋아졌어요.
# 앞으로도  좋은 공연 기대하며  응원합니다!!!^'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.9748, 부정 확률: 0.0252
#
# --- 예측 결과 ---
# 리뷰: 'Sean'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '이름처럼 산다.
# 엄마의 청춘을 알아주는 임영웅이 너무좋더라
# 진정한 히어로'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.7816, 부정 확률: 0.2184
#
# --- 예측 결과 ---
# 리뷰: '폭룡적_카리나_812159'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '영화관내 모든 연령의 엄마들을 소녀로 만들어주는 영화 진짜 영웅 히어로였다'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.6572, 부정 확률: 0.3428
#
# --- 예측 결과 ---
# 리뷰: '신이난_송혜교_519142'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '임영웅 아임히어로더스타디움  공연 영화는 팬들을 향한 진심과 아티스트 로써 전심을 합해 감동과 전률을 느끼게 해준다. 눈과 귀가 즐겁고 가슴을 울리는 영화'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.9352, 부정 확률: 0.0648
#
# --- 예측 결과 ---
# 리뷰: '똑똑한_박찬욱_297898'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '임영웅 최고입니다 .... 영화 다시 보겠습니다'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.9336, 부정 확률: 0.0664
#
# --- 예측 결과 ---
# 리뷰: '친절한_침착맨_644908'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '임영웅의 노력과 진심이 느껴졌다'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.6976, 부정 확률: 0.3024
#
# --- 예측 결과 ---
# 리뷰: '화가난_강동원_607560'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '팬들을 사랑하는 마음이 진심이라는 마음이 느껴지고 영화를 보고  감동을 받았어요.'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.9611, 부정 확률: 0.0389
#
# --- 예측 결과 ---
# 리뷰: '고고한_김혜수_897547'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '임영웅은역시임영웅이라는걸영화보며다시한번확인~
# 라이브실력영상미그리고멋진아티스트준비과정
# 모든게퍼팩트'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '덤덤한_봉준호_288917'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '최고의영상ㆍ감동입니다'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '배려와존중하기'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '명품가수 임영웅의 아임 히어로 더스타디움은 볼때마다 행복하고 볼때마다 놀라움이네요 하나하나 섬세하지만 철저한 준비로 행복을주려 노력한 모습에 또 반합니다 모든날 모든순간 사랑합니다'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.9093, 부정 확률: 0.0907
#
# --- 예측 결과 ---
# 리뷰: '귀여운_침착맨_569931'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '블인때 봤을 때 부터 그냥저냥 했습니다'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4725, 부정 확률: 0.5275
#
# --- 예측 결과 ---
# 리뷰: '색시주뇨비'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '확실히 제목을 잘못 지은것 같아요'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.5523, 부정 확률: 0.4477
#
# --- 예측 결과 ---
# 리뷰: '폭룡적_엠마스톤_284650'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '열받네? 근데 현실이지...  아 근데 재밌네!'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.7876, 부정 확률: 0.2124
#
# --- 예측 결과 ---
# 리뷰: '도도한_567681'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '그저 그래요'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.1192, 부정 확률: 0.8808
#
# --- 예측 결과 ---
# 리뷰: '호날두'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '진짜 이렇게까지 밖에 못만드냐 소재는 좋은데 하'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.1415, 부정 확률: 0.8585
#
# --- 예측 결과 ---
# 리뷰: '작두'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# ...
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '그냥 뭔가 공감되는 여행이다. 여행은 원래 지지고 볶는게 맛이다.'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.5044, 부정 확률: 0.4956
#
# --- 예측 결과 ---
# 리뷰: '행복한_팀버튼_326290'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '나는솔로 애청자로서 익숙한사람들의 새로운 감정선을
# 시청자에게선사 즐겨 보고있읍니다'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.7724, 부정 확률: 0.2276
#
# --- 예측 결과 ---
# 리뷰: '구름계단'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '사소한 거짓으로 시작된 안나의 삶
# 그 거짓말들로 삶을 쉽게 성공으로 이끈다
# 리플리증후군을 잘 표현했고
# 거짓말 한 안나? 주변인들?
# 과연 악은 누군가도 생각하게 된다'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.8045, 부정 확률: 0.1955
#
# --- 예측 결과 ---
# 리뷰: '행복한_팀버튼_179087'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '몰입감장난아니고 조마조마하면서 봤음...연출 배우들 연기 다 넘잘하고 다음편 궁금함ㄷ ㄷ드라마아니라 영화같아요'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.6732, 부정 확률: 0.3268
#
# --- 예측 결과 ---
# 리뷰: '덤덤한_레이놀즈_216531'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '퀄도 좋고 전개도 빨라서 흡입력 있게 잘 봤습니다. 수지가 거의 극을 혼자 이끌어 가는데 연기까지 잘하니 몰입도가 높고 들킬까봐  조마조마 하면서 긴장하며 봤어요 진짜 만족합니다.'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.9110, 부정 확률: 0.0890
#
# --- 예측 결과 ---
# 리뷰: '스완이'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '안나의 사연이 딱하면서도 위태로운 모습에 안절부절하는 나의 모습을 발견하게 된다.. 정신을 차리고 보니 밤을 새서 완주해버린 나는 한동안 안나에 심취하게 되었다ㅠㅠ 몰입력 최고👍'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.9134, 부정 확률: 0.0866
#
# --- 예측 결과 ---
# 리뷰: '팝콘탐지기🍿'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '거짓투성이의 세상 보이는게 전부가 아니고 거짓말이 또 다른 거짓말을 불러온다'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4677, 부정 확률: 0.5323
#
# --- 예측 결과 ---
# 리뷰: '양기자(YCU)'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '리플리 증후군과 정치 스릴러의 결합이 이 시대에 주는 의미, 그리고 '수지''
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.6923, 부정 확률: 0.3077
#
# --- 예측 결과 ---
# 리뷰: '까칠한 디카프리오_137121'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.7148, 부정 확률: 0.2852
#
# --- 예측 결과 ---
# 리뷰: '몰입도 있고 스피디한 전개로 몰아친다. 리플리 증후군 주인공에게 왜이렇게 감정이입이 되는지. 들키지 않았으면 좋겠다 솔직히. 거짓말로 살고 싶을 정도로 인생이 시궁창같다면 말이다'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.6073, 부정 확률: 0.3927
#
# --- 예측 결과 ---
# 리뷰: '도경수없이말없비없수'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '작은 거짓말이 눈덩이처럼 커져 버린 인생을 어떻게 감당하려나하고 가슴 졸이며 보게 된 드라마'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.9198, 부정 확률: 0.0802
#
# --- 예측 결과 ---
# 리뷰: '왕순kim'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '<감독판 시청완료> 쉽게 시작한 거짓말은 끊기 힘들다. ✅️ 1.스토리 전개가 빨라서 좋았다. 그러나 용두사미인거는 좀 아쉽다.
# 2.수지를 비롯한 배우들 연기력이 참 좋았다.'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4973, 부정 확률: 0.5027
#
# --- 예측 결과 ---
# 리뷰: '선우'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '캐스팅, OST, 연출 다 마음에 든다. 4화까지 내쳐 달리다 5화부터 동력을 약간 잃지만 결말이 뻔하지 않아 좋았음.'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.7915, 부정 확률: 0.2085
#
# --- 예측 결과 ---
# 리뷰: '샤일록'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '부위별로 나눠서 품평하고, 오래되면 신선하지 않다고 버려진다면 인간은 한낱 고깃덩어리와 다를 바 없다'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.3520, 부정 확률: 0.6480
#
# --- 예측 결과 ---
# 리뷰: '토니스탱크'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '찬란하고 기괴하며, 역겨우면서도 아름다운 영화.
# 씨발.'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.8078, 부정 확률: 0.1922
#
# --- 예측 결과 ---
# 리뷰: '오징어참치김밥'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '다 좋은데 마지막에 분수쇼는 좀...'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.7942, 부정 확률: 0.2058
#
# --- 예측 결과 ---
# 리뷰: '빌런팝콘'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '친절히 뇌뚜껑을 직접 열고 쑤셔 넣어주는 메시지.'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.5852, 부정 확률: 0.4148
#
# --- 예측 결과 ---
# 리뷰: '나무'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.3297, 부정 확률: 0.6703
#
# --- 예측 결과 ---
# 리뷰: '자신의 모든 걸 싫어해 본 사람들에게 바치는 영화'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.7762, 부정 확률: 0.2238
#
# --- 예측 결과 ---
# 리뷰: '씨네소울'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '영화 서브스턴스 뜻 정보 출연진 관람평점 줄거리 리뷰 결말 후기 스포 쿠키 외모지상주의를 신랄하게 비판하는 하드고어 영화추천'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4980, 부정 확률: 0.5020
#
# --- 예측 결과 ---
# 리뷰: '아이럽무비'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '몰입도 색감 너무 좋다 다만 후반부에 힘들다....'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.9409, 부정 확률: 0.0591
#
# --- 예측 결과 ---
# 리뷰: '쏨땀'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '롤코탔는데 내려주지않음 영원히'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.6033, 부정 확률: 0.3967
#
# --- 예측 결과 ---
# 리뷰: '박수민'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '난 왜 이 영화 슬프지'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.7448, 부정 확률: 0.2552
#
# --- 예측 결과 ---
# 리뷰: '장혜령'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '각자의 욕망의 발견된 그곳. 서로 행복하면 된거야. 원작 보더 더 나아간 반전에서..'헉'. 한국 상업영화에서 보기 드문 서사.'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.6691, 부정 확률: 0.3309
#
# --- 예측 결과 ---
# 리뷰: '미생'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.5005, 부정 확률: 0.4995
#
# --- 예측 결과 ---
# 리뷰: '몰입도최고'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.5887, 부정 확률: 0.4113
#
# --- 예측 결과 ---
# 리뷰: '샤일록'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '자극이라는 벽 속에 갇혀버린 주제의식'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.6208, 부정 확률: 0.3792
#
# --- 예측 결과 ---
# 리뷰: '바이올렛순임'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '긴장감 빠진 스릴러잖아! 이게 뭔 영화야? 보고 싶지도 않은 정사씬이 너무 길어!'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.1550, 부정 확률: 0.8450
#
# --- 예측 결과 ---
# 리뷰: '아카소에이지'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '박지현과 조여정의 선후배없는 연기배틀 (송승헌은 늘 그렇듯 아쉬워)'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4227, 부정 확률: 0.5773
#
# --- 예측 결과 ---
# 리뷰: '화가난_에스파_616681'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '동성애 영화네요!~~~~'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.6648, 부정 확률: 0.3352
#
# --- 예측 결과 ---
# 리뷰: '재밌는_티모시_855643'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '두 여배우 연기 외에는  별로.    웬 731부대 설명까지. 비쥬얼도 인간중독만  못  함.'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.0548, 부정 확률: 0.9452
#
# --- 예측 결과 ---
# 리뷰: '나이트시네마'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '어색한 초반
# 흥미진진한 중반
# 어이없는 후반'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.1307, 부정 확률: 0.8693
#
# --- 예측 결과 ---
# 리뷰: '고고한_짱구_930829'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '어저께 시사회에서 봤습니다. 넷플에서 원작도 봤는데 원작보다 구성이 매끄럽고, 각색이 잘 된 느낌이었습니다.
# 수위는 높지만 예쁘게 보여져서 괜찮았습니다. 마지막 의외의 결말!'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.7925, 부정 확률: 0.2075
#
# --- 예측 결과 ---
# 리뷰: 'movielover'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '의외로 몰입도 높은 에로틱 스릴러. 박지현의 강렬한 연기'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.8545, 부정 확률: 0.1455
#
# --- 예측 결과 ---
# 리뷰: '귀여운_침착맨_569931'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '생각 보다 잔인해서 놀랐고, 스토리가 구성이 나름 잘되어 있으나, 결정력이 많이 떨어집니다.'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.3982, 부정 확률: 0.6018
#
# --- 예측 결과 ---
# 리뷰: '호잉이아빠'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '니들은 왜 일을 크게 벌릴 줄만 아냐 (대사 중)'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.3142, 부정 확률: 0.6858
#
# --- 예측 결과 ---
# 리뷰: '양기자(YCU)'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '제목이 곧 작품의 주제이기에, 매우 정직한 흐름으로 전개된다.'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4451, 부정 확률: 0.5549
#
# --- 예측 결과 ---
# 리뷰: '그렇게간단하지가않음'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '아 스트레스 받아 돈이 머라고 진짜 도른 거 다 갖다버려'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.0700, 부정 확률: 0.9300
#
# --- 예측 결과 ---
# 리뷰: '박스타'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '다들 연기는 좋았음. 감독님이 반전을 아주 좋아하나 봐요'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.8086, 부정 확률: 0.1914
#
# --- 예측 결과 ---
# 리뷰: '연분홍빛춤출무렵'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '스토리가 일관되고 스피드 있게 진행되지만 반전의 힘이 약하고 주인공들의 인간미를 들어내기 위한 장치가 적어 인물들이 스토리에 기계적으로 묻힌듯한 느낌! 배우가 아깝다.'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.1251, 부정 확률: 0.8749
#
# --- 예측 결과 ---
# 리뷰: 'junhyeong416'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '이 영화에 손을 대지 마라'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.2392, 부정 확률: 0.7608
#
# --- 예측 결과 ---
# 리뷰: '도파민중독'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '초반엔 내용이 궁금했다,중반엔 결말이 궁금했다
# 후반에 영화의 의도가 궁금해졌다 결말을 보며 난 생각했다
# 6년..? 그냥 쭉 묵히지..'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4141, 부정 확률: 0.5859
#
# --- 예측 결과 ---
# 리뷰: '함수정'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '더러운 돈에 손대지 마라'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.1380, 부정 확률: 0.8620
#
# --- 예측 결과 ---
# 리뷰: 'BIGMAC_bro'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '그냥저냥 볼만은 함. 더 졸였으면 좋았을 것 같은 영화'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.2501, 부정 확률: 0.7499
#
# --- 예측 결과 ---
# 리뷰: '필름 판타지아'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.2653, 부정 확률: 0.7347
#
# --- 예측 결과 ---
# 리뷰: '영화 뿐만 아니라 극장을 즐기던 이들의 행복한 표정을 잊을 수 없다. 어쩌면 오늘날의 우리는 영화 ‘속’으로만 너무 파고들어 메세지가 무엇이고 스토리가 어떤지에만 집중하는지도 모르...'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.9046, 부정 확률: 0.0954
#
# --- 예측 결과 ---
# 리뷰: '슈가슈가룬'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '어린 시절을 어떻게 보냈는가가 누군가의 삶에 얼마나 큰 영향을 끼치는지 알게 해주는 작품
# 엔딩과 아주 유명한 OST가 너무나 기억에 남는 영화'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.9250, 부정 확률: 0.0750
#
# --- 예측 결과 ---
# 리뷰: '16'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '추억들이 쌓여 만들어진 인생이란 영화'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.8175, 부정 확률: 0.1825
#
# --- 예측 결과 ---
# 리뷰: '영알못'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '추억은 한 편의 영화처럼'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.3265, 부정 확률: 0.6735
#
# --- 예측 결과 ---
# 리뷰: '미생'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.5005, 부정 확률: 0.4995
#
# --- 예측 결과 ---
# 리뷰: '영화같은인생과닮아있다'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '블루토토'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '어렸을때 티비에서 해주던 영화
# 졸린 눈을 비비면서 보던 명작'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.9196, 부정 확률: 0.0804
#
# --- 예측 결과 ---
# 리뷰: '나의아저씨'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '어린시절의추억에젖으며감상하게돠는영화'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '키네키노'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '영화같은 인생을 꿈꾸지만,
# 이미 우리는 인생이라는 영화속을 살고 있음을'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.8803, 부정 확률: 0.1197
#
# --- 예측 결과 ---
# 리뷰: '박성현'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '감독판을 보면 알프레도의 마지막 선물이 조금 다른 의미로 받아들여진다. 알프레도는 영화에 대한 토토의 재능과 열정을 알았고, 엘레나가 남긴 쪽지를 고의로 숨겼다.
#
# 만약 그 때 ...'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.6647, 부정 확률: 0.3353
#
# --- 예측 결과 ---
# 리뷰: '뭐_글쎄'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '영화 좋아하는 사람들에게 주는 선물같은'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.6852, 부정 확률: 0.3148
#
# --- 예측 결과 ---
# 리뷰: 'Marigold'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '사람이 죽는데 웃고있어요'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.2906, 부정 확률: 0.7094
#
# --- 예측 결과 ---
# 리뷰: '나비소년'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '그래. 코미디영화는 그냥 웃기기만 하면 되는거다. 어줍잖게 교훈, 감동 같은거 넣을거 없이 그냥 웃기게만 만들면 되는거다. 같이 보러간 사람이랑 영화보고 즐거우면 된거니까.'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.3867, 부정 확률: 0.6133
#
# --- 예측 결과 ---
# 리뷰: '영화조아'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '이희준 진짜 ㅋㅋㅋㅋ귀엽고 웃기고 멋있고 섹시하고 매력적인건 자기가 다 함 ㅋㅋㅋㅋ 진짜 미치겠음'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.9014, 부정 확률: 0.0986
#
# --- 예측 결과 ---
# 리뷰: '가보자고'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '어떤 내용이냐고 물으면 뭐라고 해줘야할지 모르겠는데 개애애애애애웃기고 잔인하고 사람이 죽는데 웃고 있는 이상한 영화 🤣🤣 오늘의 교훈: 영어공부를 하자 (?)'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.2607, 부정 확률: 0.7393
#
# --- 예측 결과 ---
# 리뷰: '슈가슈가룬'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: 'B급 코미디물을 아주 좋아라 하진 않지만 적어도 내 취향은 아니었던 걸로..
# 웃긴 웃었는데 어이가 없어서 웃은 기억이 더 많음. 좀 킹받게 웃기는 작품인듯
# 배우들 연기는 좋았다'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.3429, 부정 확률: 0.6571
#
# --- 예측 결과 ---
# 리뷰: '귀여운_침착맨_569931'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '이게 왜 창고영화였는지 아쉬울 따름 ㅎㅎㅎ'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.2970, 부정 확률: 0.7030
#
# --- 예측 결과 ---
# 리뷰: '재밌는_신동엽_248133'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '비싼돈내고 중간에 나와보긴 첨이다. 이것도 영화냐'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.0183, 부정 확률: 0.9817
#
# --- 예측 결과 ---
# 리뷰: '리무진'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: ''킬링 로맨스'와 '죽지 않는 인간들의 밤'의 상위 호환ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.5404, 부정 확률: 0.4596
#
# --- 예측 결과 ---
# 리뷰: '양기자(YCU)'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '원작이 있긴 한데, 이렇게 한국 상업 영화 보면서 웃음 터진 시사회는 좀 오랜만이라 반가운 B급 호러 코미디'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.2835, 부정 확률: 0.7165
#
# --- 예측 결과 ---
# 리뷰: '벌크업흰둥이'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '기괴한데 재밌는 매력적인 B급영화'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.8902, 부정 확률: 0.1098
#
# --- 예측 결과 ---
# 리뷰: '키노'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '말로 표현할수 없이 아름답고 맘에서 지워지지 않는 영화'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.8835, 부정 확률: 0.1165
#
# --- 예측 결과 ---
# 리뷰: 'misty S'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '정말 오랫만이었다.
# 영화가 다 끝나도록 자리를 뜨지 못했던 건 정말 오랫만에 있는 일이었다.
# 영화 속의 주인공, 특히 어린 남자주인공의 감정과 동화되어, 그의 눈물이 나의 눈물이...'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.9794, 부정 확률: 0.0206
#
# --- 예측 결과 ---
# 리뷰: '규민'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '사랑이란 감정은 그 어떤 때보다 많은 감각들이 나타나고 되살아난다. 특히 첫사랑은 그 어느 순간보다 예민하기도 하지만 서툴기도한 시간들이다. <콜 미 바이 유어 네임>은 오감을 넘...'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.7616, 부정 확률: 0.2384
#
# --- 예측 결과 ---
# 리뷰: '선우'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '말로써 옮길 수 없는, 오직 영화만이 가질 수 있는 무엇을 감상할 때가 더러 있다. 이를테면 루카 구아다니노가 담아내는 공간 같은 것들. 그러나 그의 신작 <콜 미 바이 유어 네임...'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.5061, 부정 확률: 0.4939
#
# --- 예측 결과 ---
# 리뷰: '타잔'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.3979, 부정 확률: 0.6021
#
# --- 예측 결과 ---
# 리뷰: '* 이 리뷰는 지극히 개인적인 감정으로 쓰여진 것 임을 밝힌다.
#
#
#
#
# <콜 미 바이 유어 네임>속에는 어떠한 고민도 없다. 두 남자가 사랑하는 이야기라고는 하지만, 둘만이 살아가...'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4041, 부정 확률: 0.5959
#
# --- 예측 결과 ---
# 리뷰: '보문동꿀주먹'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '그들의 사랑이 나의 것과 별 반 다르지 않을지도.'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.8804, 부정 확률: 0.1196
#
# --- 예측 결과 ---
# 리뷰: '알량한'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '아메리칸 파이에 버금가는 복숭아가 나오는데, 두 남자의 사랑 사이를 메우는 여자들이 그런 취급을 당하고 있다. 고대 그리스인들 같다. 남자끼리의 사랑은 숭고하고, 여자와의 사랑은 ...'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.7913, 부정 확률: 0.2087
#
# --- 예측 결과 ---
# 리뷰: '시크캣'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '결핍이 만드는 욕망을 사랑이라고도 부른다.'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4578, 부정 확률: 0.5422
#
# --- 예측 결과 ---
# 리뷰: '타는태양'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '겉보기에 좋은 영화'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.9574, 부정 확률: 0.0426
#
# --- 예측 결과 ---
# 리뷰: '샨당'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '누구보다 뜨겁고 아프고 절절한 첫사랑의 열병을 겪은 엘리오.'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.7231, 부정 확률: 0.2769
#
# --- 예측 결과 ---
# 리뷰: '이오더매드문'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '넷플릭스 역시 이 투자게임에 신중하게 다시 생각해봐야 한다'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.7280, 부정 확률: 0.2720
#
# --- 예측 결과 ---
# 리뷰: '왕순kim'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '넷플릭스가 아니었다면 한국에서 이런 드라마가 나올 수 있었을까, 뛰어난 배우들의 연기력, 하지만 후반부로 갈수록 호흡이 느려지고 개연성이 사라진다... 흥미로웠지만 아쉬웠다.'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.5644, 부정 확률: 0.4356
#
# --- 예측 결과 ---
# 리뷰: '김렁클'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '그동안 한국영화에서 볼 수 없었던 새로운 장르를 개척했지만 짜깁기에 그친 K-배틀로얄 장르의 한계'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4866, 부정 확률: 0.5134
#
# --- 예측 결과 ---
# 리뷰: '주이지'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '내 이리 잔인할 줄 몰랐쏘'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.3881, 부정 확률: 0.6119
#
# --- 예측 결과 ---
# 리뷰: '두둥탁'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '허술한 부분도 적지 않아 아쉬움도 크지만 전체적으로 마음에 들었기에 시즌2가 나온다면 기대할 것이다.'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4631, 부정 확률: 0.5369
#
# --- 예측 결과 ---
# 리뷰: '귀여운_침착맨_569931'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '이것만 본 사람이 우승자'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.5792, 부정 확률: 0.4208
#
# --- 예측 결과 ---
# 리뷰: '임박사'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '설정이 말도 안된다고 생각하면서도 진짜 어디선가 이런 게임이 진행중일까 싶었다. 주인공은 생존할 것이란 걸 알면서도 게임결과 나올때마다 손에 땀이 나더라.'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.2538, 부정 확률: 0.7462
#
# --- 예측 결과 ---
# 리뷰: '심심풀2'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '아... 욕하면서 봤지만 솔직히 한번 켜면 9화까지 정주행안 할수가 없는 아주 자극적이고 볼만한 작품
# 아쉬운 부분은 많지만 추천'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.5275, 부정 확률: 0.4725
#
# --- 예측 결과 ---
# 리뷰: '선우'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '아쉬운 게임, 잃지 않는 완성도'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.5896, 부정 확률: 0.4104
#
# --- 예측 결과 ---
# 리뷰: '천아손'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.4799, 부정 확률: 0.5201
#
# --- 예측 결과 ---
# 리뷰: '설국열차의 코믹버젼같달까? 어쩄든 잔인한  주제와 내용과는  전혀 다르게 신선한 진행으로 무겁지 않고 재미있게 본거같다  하지만 뭔가 인생에 씁쓸함은 다 느끼고 만듯'
# 리뷰 반응: 긍정(Positive)
# 긍정 확률: 0.8438, 부정 확률: 0.1562

# %%
review_text = input("리뷰 입력")

# 입력한 리뷰를 모델에 넣어 예측
sentiment, proba = predict_sentiment_fc(review_text)

# 예측 결과 출력
print(f"예측 결과: {sentiment}")

if sentiment == "부정(Negative)":
    print("만족스럽지 않은 콘텐츠였나봐요. 더 좋은 콘텐츠를 추천해드릴게요!")
else :
    print("마음에 꼭 드셨군요!")
# Out:
# --- 예측 결과 ---
# 리뷰: '별로임'
# 리뷰 반응: 부정(Negative)
# 긍정 확률: 0.0315, 부정 확률: 0.9685
# 예측 결과: 부정(Negative)
# 만족스럽지 않은 콘텐츠였나봐요. 더 좋은 콘텐츠를 추천해드릴게요!
